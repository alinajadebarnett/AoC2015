# %% [markdown]
# https://adventofcode.com/2015/day/12

# %%
import json

# %%
input = r'''{"e":[[{"e":86,"c":23,"a":{"a":[120,169,"green","red","orange"],"b":"red"},"g":"yellow","b":["yellow"],"d":"red","f":-19},{"e":-47,"a":[2],"d":{"a":"violet"},"c":"green","h":"orange","b":{"e":59,"a":"yellow","d":"green","c":47,"h":"red","b":"blue","g":"orange","f":["violet",43,168,78]},"g":"orange","f":[{"e":[82,-41,2,"red","violet","orange","yellow"],"c":"green","a":77,"g":"orange","b":147,"d":49,"f":"blue"},-1,142,136,["green","red",166,-21],"blue","orange",{"a":38}]},"orange","yellow"],"green",-22,[37,[4,-40,["red","yellow",["yellow",177,"red","blue",139,[55,13,"yellow","violet",-21,140,"yellow",117],"blue","blue",106],"blue",{"a":23}],183,92,"orange","green"],"orange"],-5],"c":[{"e":{"e":-13,"c":-11,"a":{"a":49,"b":189},"g":144,"b":186,"d":{"e":[146,[32,"violet","red","orange",-22],"blue","violet",57,{"e":12,"a":"red","d":37,"c":-13,"h":"green","b":-27,"g":"orange","f":"orange","i":"red"},56,-1,"red",-25],"c":-14,"a":[["orange","green","green","red",-25],-16,104,177,"red"],"g":"red","b":"blue","d":2,"f":"green"},"f":[{"e":{"c":-15,"a":"green","b":144,"d":-32},"c":"yellow","a":["blue","blue"],"b":"yellow","d":135,"f":"violet"}]},"a":{"e":"blue","a":[145,128,"orange","violet",23,["orange",[78,"yellow","orange","orange","orange","green",122,-35,"blue"],159,114]],"d":"yellow","c":{"e":[100,"green",{"e":"blue","a":36,"d":84,"j":"orange","c":"blue","h":118,"b":85,"g":"violet","f":"blue","i":27},"blue","blue"],"a":"red","d":"blue","j":[159,22,"violet","orange","blue","orange","blue",186,175,{"e":29,"a":150,"d":"green","c":129,"h":138,"b":-29,"g":7,"f":"red","i":"violet"}],"c":"yellow","h":["blue",-9,41,{"e":144,"c":"violet","a":161,"b":116,"d":126,"f":197},173,123,50,"red",154],"b":-23,"g":"orange","f":"green","i":"red"},"h":26,"b":30,"g":106,"f":{"c":{"e":-28,"c":["red","violet","blue","orange","yellow","violet",-30,134,0],"a":-37,"b":41,"d":143},"a":121,"b":"yellow","d":[198,"yellow"]}},"d":{"e":-2,"a":"green","d":{"a":0,"b":"blue"},"j":"violet","c":[{"e":"violet","a":"orange","d":"violet","c":-36,"h":68,"b":195,"g":41,"f":63},11,-20,{"e":[100,43,183],"a":"yellow","d":["orange","yellow","violet","yellow",143,162,-23,168,145,-33],"j":80,"c":"orange","h":{"a":"orange"},"b":"violet","g":-21,"f":-38,"i":"green"},{"e":"red","a":81,"d":3,"c":"blue","h":[167,"blue","yellow",135,64,116,134,14,160],"b":"red","g":"blue","f":"green"},["red",[139,"orange","blue","blue","orange","blue"],"orange","red",113,26,"yellow","yellow",85]],"h":[[117],"yellow",{"e":187,"c":"orange","a":-22,"b":["orange"],"d":68},154,["green","orange","blue",87,"green","orange",46,"violet"],{"a":{"e":178,"c":"blue","a":-2,"g":99,"b":"orange","d":-34,"f":"green"}},"blue"],"b":"violet","g":[
ow","i":147},"d":58,"c":"violet","h":{"a":{"e":27,"a":"orange","d":181,"c":142,"h":195,"b":"yellow","g":44,"f":"yellow"}},"b":-14,"g":"red","f":{"a":154},"i":90},"orange",{"a":"blue","b":-11},["yellow",[38,-34,"orange",57],"orange",98,"violet","violet",{"a":134},[24,"blue","blue",172,114],10],[{"a":["yellow","green"]},166,"blue",["blue",{"e":"blue","c":-6,"a":"green","b":"green","d":"green","f":50},-44,{"e":"violet","a":"yellow","d":-27,"j":33,"c":"orange","h":146,"b":"green","g":30,"f":"violet","i":"violet"},"blue","red","violet",6]],113],"g":{"e":{"e":"red","a":125,"d":183,"j":74,"c":["green","yellow"],"h":12,"b":["green",-38,"yellow"],"g":71,"f":"blue","i":"blue"},"a":["green",86,28,[55,127,"blue",172,"green",83,"green","violet",{"a":53},"blue"],{"a":181,"b":57},[28,"violet"],"red",{"a":138},198],"d":"yellow","c":[{"e":"violet","c":65,"a":"green","b":{"e":"orange","a":68,"d":"orange","c":"green","h":161,"b":"green","g":"green","f":13},"d":-38},"blue",{"e":73,"a":40,"d":"green","c":"red","h":"yellow","b":117,"g":178,"f":170},"yellow",188],"h":{"a":-21},"b":{"c":86,"a":["green","green",170,"blue",-40,"yellow","red",10],"b":[["green","yellow",2,"violet",-30,"yellow","red",-40,"orange","violet"],"red",58,165,"red"],"d":13},"g":{"a":63},"f":"violet"},"f":["green"],"i":[["yellow","yellow","red",{"e":-5,"c":124,"a":"yellow","g":"violet","b":"orange","d":"violet","f":149},-16,9],"violet",-43,{"c":9,"a":52,"b":179,"d":74},"violet",[{"e":-30,"a":82,"d":"green","j":49,"c":{"e":"green","a":"violet","d":"yellow","j":"blue","c":37,"h":"violet","b":48,"g":12,"f":"green","i":"red"},"h":58,"b":["yellow","blue","blue",29,"orange","green","green",0],"g":128,"f":"orange","i":91},[181,"red","green","violet","red","green","orange",{"e":"green","a":"yellow","d":"green","c":24,"h":194,"b":128,"g":"red","f":162,"i":"violet"},191],"red","violet","yellow","red"],141,123]},"c":{"a":95},"h":{"a":138},"b":118,"g":"green","f":0,"i":"violet"}}'''

# %%
x = json.loads(input)

# %%
if type(x) == dict:
  print("True")
type(x)
# Out:
# True
# dict

# %%
# https://stackoverflow.com/questions/55926688/python-create-tree-from-a-json-file

def create_tree_from_JSON(json):  # root case
    tree = Tree()
    node_0 = TreeNode("ROOT")
    tree.root = node_0
    parent = node_0
    _walk_tree(json, parent)

def _walk_tree(json, parent):  # recursive case
    for key in json:
        if isinstance(json[key], dict):
            head = TreeNode(key)
            _walk_tree(json[key], head)
        else:
            node = TreeNode(key)
            node.add_child(TreeNode(json[key]))
        parent.add_child(node)

def treeify(data) -> dict:
    if isinstance(data, dict):  # already have keys, just recurse
       return {key: treeify(children) for key, children in data.items()}
    elif isinstance(data, list):  # make keys from indices
       return {idx: treeify(children) for idx, children in enumerate(data, start=1)}
    else:  # leave node, no recursion
       return data

treeify(x)
# Out:
# {'a': {'a': {'a': {1: 'violet',
#     2: {1: -30, 2: 117},
#     3: {1: 78, 2: 31},
#     4: 74,
#     5: 197,
#     6: 'red',
#     7: 'orange',
#     8: 95},
#    'b': {1: 'violet',
#     2: {'a': 137,
#      'b': 'orange',
#      'c': 11,
#      'd': 47,
#      'e': {'a': {'a': -25,
#        'b': 48,
#        'c': 'green',
#        'd': 70,
#        'e': 'blue',
#        'f': 'orange',
#        'g': 'violet',
#        'h': 'violet'},
#       'b': {'a': 'blue',
#        'b': 192,
#        'c': 'green',
#        'd': 198,
#        'e': 26,
#        'f': 86,
#        'g': 'violet'},
#       'c': 136,
#       'd': 'yellow',
#       'e': 91,
#       'f': 'blue',
#       'g': 'orange',
#       'h': 90},
#      'f': {'a': 45,
#       'b': 157,
#       'c': -38,
#       'd': 'violet',
#       'e': 'blue',
#       'f': -13,
#       'g': 104,
#       'h': 4,
#       'i': 'yellow',
#       'j': 146},
#      'g': 'orange',
#      'h': 'yellow'},
#     3: {'a': 'blue',
#      'b': 148,
#      'c': 'blue',
#      'd': 'green',
#      'e': 191,
#      'f': {'a': 167,
#       'b': {1: -42,
#        2: 147,
#        3: 166,
#        4: 74,
#        5: -32,
#        6: 'orange',
#        7: 'violet',
#        8: 'yellow'},
#       'c': 'red',
#       'd': 'green',
#       'e': 57,
#       'f': 71},
#      'g': 'blue',
#      'h': -19},
#     4: 'green',
#     5: {1: 184,
#      2: 'yellow',
#      3: {1: {1: 'yellow', 2: 'yellow'},
#       2: 'green',
#       3: {'a': 1,
#        'b': 144,
#        'c': 'yellow',
#        'd': 44,
#        'e': -24,
#        'f': 'green',
#        'g': 'violet',
#        'h': 'yellow',
#        'i': -7},
#       4: 86,
#       5: 119,
#       6: 52,
#       7: 'orange',
#       8: {1: 'red', 2: 'red', 3: 18, 4: 'orange', 5: 192, 6: 116},
#       9: 120,
#       10: 109}},
#     6: {1: 'violet',
#      2: -14,
#      3: 'violet',
#      4: {'a': -15,
#       'b': 'blue',
#       'c': {'a': 'red',
#        'b': 25,
#        'c': 9,
#        'd': 'blue',
#        'e': 'green',
#        'f': 10,
#        'g': 'red',
#        'h': 'orange',
#        'i': 'green',
#        'j': 68},
#       'd': 'violet',
#       'e': -29,
#       'f': 125},
#      5: 119,
#      6: {1: 127, 2: 'violet', 3: 'green', 4: 39}}},
#    'c': {1: 96, 2: 'violet'},
#    'd': 'green',
#    'e': {'a': 'orange',
#     'b': {'a': {'a': 'green', 'b': 198, 'c': 120, 'd': 152, 'e': -11, 'f': 37},
#      'b': 77,
#      'c': 131,
#      'd': {'a': 21,
#       'b': 11,
#       'c': 'yellow',
#       'd': 'blue',
#       'e': 8,
#       'f': {'a': 80, 'b': 78, 'c': 98, 'd': 68, 'e': 148},
#       'g': 'violet',
#       'h': 'violet'}},
#     'c': -1,
#     'd': 'orange'},
#    'f': -14,
#    'g': 'green',
#    'h': {'a': 71,
#     'b': {1: -14,
#      2: {1: 28},
#      3: 'yellow',
#      4: {1: 93, 2: 'blue', 3: -24, 4: 160, 5: 35, 6: 25, 7: -32, 8: 'green'},
#      5: {'a': 'orange',
#       'b': 'yellow',
#       'c': 122,
#       'd': {'a': 179, 'b': 'blue', 'c': 53, 'd': -44},
#       'e': {1: 51,
#        2: 'red',
#        3: 64,
#        4: 'red',
#        5: 'blue',
#        6: -16,
#        7: 31,
#        8: 146,
#        9: 'blue',
#        10: 'yellow'}},
#      6: 17,
#      7: 110},
#     'c': {1: {1: 'yellow', 2: 'green', 3: 183, 4: 165, 5: -28, 6: 4, 7: 102},
#      2: -20,
#      3: 'blue',
#      4: 'violet',
#      5: {'a': 99,
#       'b': {1: 'blue', 2: -1, 3: 'blue'},
#       'c': {'a': 'yellow',
#        'b': 169,
#        'c': 'orange',
#        'd': 'red',
#        'e': 'orange',
#        'f': 48,
#        'g': 'violet',
#        'h': 'orange'},
#       'd': 104,
#       'e': 'yellow',
#       'f': 20},
#      6: 83},
#     'd': 158,
#     'e': {'a': {1: 76,
#       2: 16,
#       3: 125,
#       4: 'green',
#       5: 15,
#       6: 'violet',
#       7: 130,
#       8: 60,
#       9: 'red'},
#      'b': 'orange',
#      'c': 'green',
#      'd': -38},
#     'f': 'orange',
#     'g': 151,
#     'h': 'green',
#     'i': {'a': 'violet', 'b': {'a': {1: -24}}},
#     'j': -16}},
#   'b': 23,
#   'c': {1: 'green',
#    2: {1: 'red',
#     2: 'orange',
#     3: {'a': {'a': 'violet', 'b': 110},
#      'b': 'violet',
#      'c': 'yellow',
#      'd': {1: {1: 174, 2: 140, 3: 72},
#       2: 191,
#       3: 'yellow',
#       4: 108,
#       5: 195,
#       6: {'a': 'violet'},
#       7: 147,
#       8: 53},
#      'e': -28,
#      'f': {1: 'blue',
#       2: 'orange',
#       3: 'violet',
#       4: {1: 48, 2: 118},
#       5: 156,
#       6: 144,
#       7: -46,
#       8: 110,
#       9: {1: 'orange', 2: 'yellow', 3: 'blue', 4: 'red'},
#       10: 149},
#      'g': 'red',
#      'h': 'green',
#      'i': {'a': {'a': 'blue',
#        'b': 'orange',
#        'c': -40,
#        'd': 'orange',
#        'e': 111,
#        'f': 32,
#        'g': 'yellow',
#        'h': 13,
#        'i': 'yellow',
#        'j': 'orange'},
#       'b': -22,
#       'c': 101,
#       'd': 199,
#       'e': 'orange',
#       'f': 'yellow',
#       'g': {'a': 'blue',
#        'b': 4,
#        'c': 185,
#        'd': 195,
#        'e': 'orange',
#        'f': 112,
#        'g': 'green',
#        'h': 20,
#        'i': 147,
#        'j': 81}}},
#     4: 'yellow',
#     5: 19,
#     6: 128,
#     7: -3,
#     8: 27,
#     9: {1: 'orange',
#      2: {'a': 'yellow', 'b': 'red', 'c': 156, 'd': 20, 'e': -8, 'f': -37},
#      3: {1: {'a': 'blue', 'b': 150, 'c': 19}, 2: 'orange', 3: -12, 4: 9}}},
#    3: {1: 12,
#     2: {'a': {1: 'blue',
#       2: 184,
#       3: 'yellow',
#       4: 'orange',
#       5: {'a': 'yellow', 'b': 'green'},
#       6: 88,
#       7: -19,
#       8: 60,
#       9: 'yellow'},
#      'b': 191,
#      'c': 162,
#      'd': -6,
#      'e': 'blue',
#      'f': 'violet',
#      'g': 'yellow'}},
#    4: {'a': 'orange',
#     'b': {'a': 'violet',
#      'b': {1: 'orange',
#       2: 'orange',
#       3: 'violet',
#       4: {'a': 'red',
#        'b': 6,
#        'c': 153,
#        'd': 163,
#        'e': 'red',
#        'f': 17,
#        'g': 'blue',
#        'h': 'green',
#        'i': 63},
#       5: 163,
#       6: {1: 164, 2: -41, 3: 'violet', 4: 'violet', 5: 126}}},
#     'c': 'yellow',
#     'd': -38}},
#   'd': {'a': -29,
#    'b': {'a': 192,
#     'b': {1: 'violet',
#      2: 'yellow',
#      3: 65,
#      4: {'a': 'red',
#       'b': 176,
#       'c': {'a': 'violet',
#        'b': 'blue',
#        'c': 'yellow',
#        'd': 'orange',
#        'e': 'violet'}},
#      5: 192}},
#    'c': {'a': 'yellow', 'b': 97, 'c': 98},
#    'd': 'orange'}},
#  'b': {1: {'a': 81,
#    'b': {1: 'orange'},
#    'c': 45,
#    'd': 'violet',
#    'e': 'yellow',
#    'f': {1: -3,
#     2: 'red',
#     3: 146,
#     4: 186,
#     5: 'orange',
#     6: 'red',
#     7: 'blue',
#     8: {'a': 'yellow',
#      'b': 'blue',
#      'c': 22,
#      'd': -2,
#      'e': 'green',
#      'f': 'green'},
#     9: 0,
#     10: 180}},
#   2: {1: {1: -36,
#     2: {1: 'orange', 2: {1: 166}, 3: 'violet'},
#     3: {'a': {1: 2,
#       2: 173,
#       3: 78,
#       4: 'violet',
#       5: 'orange',
#       6: {1: 'violet',
#        2: 'yellow',
#        3: 'blue',
#        4: 107,
#        5: 24,
#        6: -1,
#        7: 'orange',
#        8: 13,
#        9: 'green',
#        10: 'violet'}},
#      'b': 'violet',
#      'c': 86,
#      'd': 107},
#     4: 100,
#     5: {1: 'yellow',
#      2: -22,
#      3: {1: 177, 2: 69, 3: 144, 4: 84, 5: 159, 6: 'violet'},
#      4: 'green'},
#     6: {'a': 78,
#      'b': {1: {1: -48, 2: 164, 3: 'red', 4: 'blue', 5: 45},
#       2: {1: 'green', 2: 'orange', 3: 23, 4: 15, 5: 110, 6: 49, 7: 'blue'},
#       3: 'violet',
#       4: 0,
#       5: 192,
#       6: 53},
#      'c': 'blue',
#      'd': 173,
#      'e': 'green',
#      'f': 'orange',
#      'g': {1: 'blue', 2: 'violet'},
#      'h': 36,
#      'i': {1: {'a': 'green',
#        'b': 174,
#        'c': 'orange',
#        'd': 'yellow',
#        'e': 186,
#        'f': 46},
#       2: 'violet',
#       3: 188,
#       4: 'yellow',
#       5: 54,
#       6: -6,
#       7: 'blue',
#       8: 'violet',
#       9: 0,
#       10: {'a': 'yellow',
#        'b': 'violet',
#        'c': 'red',
#        'd': 'red',
#        'e': 166,
#        'f': 173,
#        'g': 32,
#        'h': 97,
#        'i': 95,
#        'j': 'blue'}}},
#     7: {'a': 58, 'b': 'blue'},
#     8: 'green',
#     9: {1: 'red',
#      2: 150,
#      3: 3,
#      4: 'orange',
#      5: 32,
#      6: 106,
#      7: {1: {1: 'blue'},
#       2: 118,
#       3: {'a': 7, 'b': 185, 'c': 178, 'd': 'violet'},
#       4: 'red',
#       5: 164,
#       6: 'red',
#       7: {1: 128, 2: 'red'},
#       8: -44},
#      8: {'a': 'orange',
#       'b': {'a': 161,
#        'b': 'orange',
#        'c': -45,
#        'd': -44,
#        'e': 91,
#        'f': 'orange',
#        'g': 122,
#        'h': 'blue'},
#       'c': 'yellow',
#       'd': 130,
#       'e': 'orange',
#       'f': 'blue',
#       'g': 'yellow',
#       'h': 'yellow'},
#      9: 139,
#      10: {'a': 97}}},
#    2: 'orange',
#    3: {1: 'orange',
#     2: 0,
#     3: 'blue',
#     4: 'red',
#     5: {'a': {'a': {1: 'red',
#        2: 164,
#        3: 'yellow',
#        4: 189,
#        5: 'blue',
#        6: 150,
#        7: 'green',
#        8: 'violet',
#        9: -35,
#        10: 33},
#       'b': 'red'},
#      'b': {'a': 'blue'},
#      'c': 92,
#      'd': 'red',
#      'e': 192,
#      'f': -31,
#      'g': 'yellow'},
#     6: 111,
#     7: 'yellow',
#     8: 'red',
#     9: {1: {1: 'green',
#       2: 'green',
#       3: 42,
#       4: -47,
#       5: {1: 88, 2: 142, 3: 'blue', 4: 59, 5: -42, 6: 'violet'},
#       6: 'green'},
#      2: 'orange',
#      3: {1: 'violet',
#       2: 'yellow',
#       3: 'violet',
#       4: 198,
#       5: 94,
#       6: 44,
#       7: 'orange',
#       8: 'green',
#       9: 'blue',
#       10: 26},
#      4: 'blue',
#      5: 'violet'}},
#    4: {'a': 118}},
#   3: {'a': {'a': {1: {1: 127,
#       2: -18,
#       3: -4,
#       4: {1: -40,
#        2: 42,
#        3: 'violet',
#        4: 167,
#        5: 'orange',
#        6: 112,
#        7: 'orange'},
#       5: 30,
#       6: 31,
#       7: 'violet',
#       8: 37},
#      2: {'a': 'green', 'b': 172, 'c': 'blue'},
#      3: {1: 141, 2: 154},
#      4: 146,
#      5: 'yellow'},
#     'b': 'blue',
#     'c': 'violet',
#     'd': -3,
#     'e': {1: 'orange', 2: -1, 3: 121, 4: 'red'}},
#    'b': {1: 'violet', 2: 'yellow', 3: 19, 4: 'red', 5: 8, 6: 138, 7: 37},
#    'c': -17,
#    'd': 'red',
#    'e': -35,
#    'f': {1: 'green',
#     2: {1: 'green',
#      2: {'a': 10,
#       'b': 56,
#       'c': 'yellow',
#       'd': 'red',
#       'e': 'red',
#       'f': {1: 'green', 2: 'red', 3: 'red'},
#       'g': 'blue'},
#      3: {1: 'violet',
#       2: 'orange',
#       3: {'a': 'green', 'b': 55, 'c': 170, 'd': 115, 'e': 7},
#       4: 'green',
#       5: 'blue'}}},
#    'g': {'a': 183,
#     'b': -36,
#     'c': {'a': 163,
#      'b': 'blue',
#      'c': {1: -23, 2: 21, 3: 'green', 4: -3, 5: 'red'},
#      'd': 'red',
#      'e': -5,
#      'f': {1: 'violet', 2: 136, 3: 'violet'}},
#     'd': 'violet'},
#    'h': -3},
#   4: {'a': 'blue',
#    'b': 'orange',
#    'c': {'a': {1: {'a': -2,
#       'b': 'violet',
#       'c': {'a': 'red', 'b': 'blue', 'c': 68},
#       'd': 'green',
#       'e': 'yellow',
#       'f': {1: 'yellow', 2: 'violet'},
#       'g': 1,
#       'h': {1: 140,
#        2: 99,
#        3: -2,
#        4: 'green',
#        5: 'orange',
#        6: 'orange',
#        7: -14,
#        8: 60,
#        9: 'red',
#        10: 'green'},
#       'i': 142},
#      2: {'a': {1: 76, 2: 1, 3: 79, 4: 36, 5: -25, 6: 'yellow', 7: 0},
#       'b': 185,
#       'c': 46,
#       'd': 54,
#       'e': {'a': 76, 'b': -17},
#       'f': 'green',
#       'g': 'yellow'}},
#     'b': {'a': {1: {1: 'violet'},
#       2: 115,
#       3: 114,
#       4: 'red',
#       5: 'orange',
#       6: 83,
#       7: -17,
#       8: -2},
#      'b': 89,
#      'c': 140,
#      'd': {'a': 46, 'b': 77, 'c': 'red', 'd': 'green', 'e': 198},
#      'e': 127,
#      'f': 'orange',
#      'g': 149,
#      'h': 'orange'},
#     'c': {1: 'yellow',
#      2: 82,
#      3: 'red',
#      4: 'orange',
#      5: {'a': 'violet',
#       'b': 182,
#       'c': 'green',
#       'd': 'orange',
#       'e': 34,
#       'f': {'a': 184,
#        'b': 170,
#        'c': 120,
#        'd': 57,
#        'e': -49,
#        'f': -3,
#        'g': 159,
#        'h': 'violet',
#        'i': 99,
#        'j': 'yellow'}},
#      6: -37,
#      7: {'a': {1: 'violet',
#        2: 154,
#        3: 'violet',
#        4: 123,
#        5: 'violet',
#        6: 148,
#        7: 105,
#        8: 'yellow',
#        9: 195},
#       'b': 159,
#       'c': {'a': 140},
#       'd': 'orange',
#       'e': 84,
#       'f': 186,
#       'g': 76,
#       'h': 'yellow'},
#      8: 183}},
#    'd': 'violet',
#    'e': {'a': 'green',
#     'b': {'a': 'yellow',
#      'b': {'a': {1: -23},
#       'b': 61,
#       'c': 'green',
#       'd': 'blue',
#       'e': {1: 27,
#        2: 'blue',
#        3: 'yellow',
#        4: -48,
#        5: -21,
#        6: -12,
#        7: 121,
#        8: 'violet'},
#       'f': 19,
#       'g': {1: 'blue'},
#       'h': 'green',
#       'i': 'violet',
#       'j': {'a': 'green', 'b': -34, 'c': 'blue', 'd': 'green', 'e': 'orange'}},
#      'c': 144,
#      'd': 'green',
#      'e': 77,
#      'f': 'orange',
#      'g': 86,
#      'h': 'green'},
#     'c': 186,
#     'd': 'yellow',
#     'e': {'a': 'blue', 'b': {1: 192, 2: 'blue', 3: 86, 4: 93}},
#     'f': 'orange',
#     'g': 'yellow',
#     'h': {1: 'violet',
#      2: 'orange',
#      3: 'orange',
#      4: 'violet',
#      5: 'red',
#      6: 'orange',
#      7: 139,
#      8: 'violet',
#      9: 'green',
#      10: {'a': 85,
#       'b': 'yellow',
#       'c': 'yellow',
#       'd': 'orange',
#       'e': 'red',
#       'f': 'orange',
#       'g': 'yellow',
#       'h': {1: 46, 2: 35, 3: 'red', 4: 'green', 5: -11, 6: 'blue'}}}},
#    'f': {'a': {1: 29,
#      2: 'yellow',
#      3: 'yellow',
#      4: 187,
#      5: 'orange',
#      6: {'a': 197,
#       'b': 90,
#       'c': 'violet',
#       'd': {1: 'green', 2: 182, 3: -2, 4: 95, 5: -8, 6: 110, 7: -38},
#       'e': 147,
#       'f': 'yellow',
#       'g': 22,
#       'h': 187,
#       'i': 'green'},
#      7: {'a': {1: 'blue', 2: 'red', 3: 140}, 'b': 'violet'},
#      8: 'blue',
#      9: 76,
#      10: 59},
#     'b': 'blue',
#     'c': {1: {'a': 'orange', 'b': 179},
#      2: 'red',
#      3: {'a': 'blue',
#       'b': 25,
#       'c': 'orange',
#       'd': 149,
#       'e': 'violet',
#       'f': -27,
#       'g': 'violet'},
#      4: {'a': 'yellow',
#       'b': 'blue',
#       'c': 145,
#       'd': 'violet',
#       'e': 'green',
#       'f': 'blue',
#       'g': 11,
#       'h': -4,
#       'i': 'violet',
#       'j': {'a': 179, 'b': 53, 'c': 67}}},
#     'd': -26,
#     'e': -11,
#     'f': 'green',
#     'g': {'a': 'green',
#      'b': 'green',
#      'c': {1: 93,
#       2: 12,
#       3: 118,
#       4: -7,
#       5: 125,
#       6: 93,
#       7: 'yellow',
#       8: 182,
#       9: 113,
#       10: 'yellow'},
#      'd': 'violet',
#      'e': 'yellow'},
#     'h': 'red',
#     'i': 'green'},
#    'g': 62},
#   5: {1: 7}},
#  'c': {1: {'a': {'a': {1: 145,
#      2: 128,
#      3: 'orange',
#      4: 'violet',
#      5: 23,
#      6: {1: 'orange',
#       2: {1: 78,
#        2: 'yellow',
#        3: 'orange',
#        4: 'orange',
#        5: 'orange',
#        6: 'green',
#        7: 122,
#        8: -35,
#        9: 'blue'},
#       3: 159,
#       4: 114}},
#     'b': 30,
#     'c': {'a': 'red',
#      'b': -23,
#      'c': 'yellow',
#      'd': 'blue',
#      'e': {1: 100,
#       2: 'green',
#       3: {'a': 36,
#        'b': 85,
#        'c': 'blue',
#        'd': 84,
#        'e': 'blue',
#        'f': 'blue',
#        'g': 'violet',
#        'h': 118,
#        'i': 27,
#        'j': 'orange'},
#       4: 'blue',
#       5: 'blue'},
#      'f': 'green',
#      'g': 'orange',
#      'h': {1: 'blue',
#       2: -9,
#       3: 41,
#       4: {'a': 161, 'b': 116, 'c': 'violet', 'd': 126, 'e': 144, 'f': 197},
#       5: 173,
#       6: 123,
#       7: 50,
#       8: 'red',
#       9: 154},
#      'i': 'red',
#      'j': {1: 159,
#       2: 22,
#       3: 'violet',
#       4: 'orange',
#       5: 'blue',
#       6: 'orange',
#       7: 'blue',
#       8: 186,
#       9: 175,
#       10: {'a': 150,
#        'b': -29,
#        'c': 129,
#        'd': 'green',
#        'e': 29,
#        'f': 'red',
#        'g': 7,
#        'h': 138,
#        'i': 'violet'}}},
#     'd': 'yellow',
#     'e': 'blue',
#     'f': {'a': 121,
#      'b': 'yellow',
#      'c': {'a': -37,
#       'b': 41,
#       'c': {1: 'red',
#        2: 'violet',
#        3: 'blue',
#        4: 'orange',
#        5: 'yellow',
#        6: 'violet',
#        7: -30,
#        8: 134,
#        9: 0},
#       'd': 143,
#       'e': -28},
#      'd': {1: 198, 2: 'yellow'}},
#     'g': 106,
#     'h': 26},
#    'b': 166,
#    'c': 'blue',
#    'd': {'a': 'green',
#     'b': 'violet',
#     'c': {1: {'a': 'orange',
#       'b': 195,
#       'c': -36,
#       'd': 'violet',
#       'e': 'violet',
#       'f': 63,
#       'g': 41,
#       'h': 68},
#      2: 11,
#      3: -20,
#      4: {'a': 'yellow',
#       'b': 'violet',
#       'c': 'orange',
#       'd': {1: 'orange',
#        2: 'yellow',
#        3: 'violet',
#        4: 'yellow',
#        5: 143,
#        6: 162,
#        7: -23,
#        8: 168,
#        9: 145,
#        10: -33},
#       'e': {1: 100, 2: 43, 3: 183},
#       'f': -38,
#       'g': -21,
#       'h': {'a': 'orange'},
#       'i': 'green',
#       'j': 80},
#      5: {'a': 81,
#       'b': 'red',
#       'c': 'blue',
#       'd': 3,
#       'e': 'red',
#       'f': 'green',
#       'g': 'blue',
#       'h': {1: 167,
#        2: 'blue',
#        3: 'yellow',
#        4: 135,
#        5: 64,
#        6: 116,
#        7: 134,
#        8: 14,
#        9: 160}},
#      6: {1: 'red',
#       2: {1: 139, 2: 'orange', 3: 'blue', 4: 'blue', 5: 'orange', 6: 'blue'},
#       3: 'orange',
#       4: 'red',
#       5: 113,
#       6: 26,
#       7: 'yellow',
#       8: 'yellow',
#       9: 85}},
#     'd': {'a': 0, 'b': 'blue'},
#     'e': -2,
#     'f': {'a': 'blue',
#      'b': 73,
#      'c': 'violet',
#      'd': 50,
#      'e': -40,
#      'f': 'red',
#      'g': 176,
#      'h': {'a': {1: -27,
#        2: 159,
#        3: 'violet',
#        4: 'red',
#        5: 130,
#        6: 83,
#        7: 'red',
#        8: 'violet',
#        9: -27},
#       'b': 'blue',
#       'c': 9,
#       'd': -42,
#       'e': 'orange',
#       'f': 81,
#       'g': {1: 114,
#        2: 'blue',
#        3: -4,
#        4: 'red',
#        5: 'red',
#        6: 'yellow',
#        7: 'green'},
#       'h': {'a': 'blue',
#        'b': 0,
#        'c': 156,
#        'd': 177,
#        'e': 'yellow',
#        'f': -43,
#        'g': 'orange',
#        'h': 'violet',
#        'i': 'orange'},
#       'i': 'red',
#       'j': 'blue'}},
#     'g': {1: 13, 2: 'yellow', 3: 43, 4: 'orange'},
#     'h': {1: {1: 117},
#      2: 'yellow',
#      3: {'a': -22, 'b': {1: 'orange'}, 'c': 'orange', 'd': 68, 'e': 187},
#      4: 154,
#      5: {1: 'green',
#       2: 'orange',
#       3: 'blue',
#       4: 87,
#       5: 'green',
#       6: 'orange',
#       7: 46,
#       8: 'violet'},
#      6: {'a': {'a': -2,
#        'b': 'orange',
#        'c': 'blue',
#        'd': -34,
#        'e': 178,
#        'f': 'green',
#        'g': 99}},
#      7: 'blue'},
#     'i': {'a': 'blue',
#      'b': {1: {'a': 'green',
#        'b': 'orange',
#        'c': 'orange',
#        'd': -49,
#        'e': 'green',
#        'f': 'violet',
#        'g': 35,
#        'h': 43,
#        'i': 'blue',
#        'j': 'green'},
#       2: 'yellow',
#       3: 32,
#       4: 'yellow'},
#      'c': {1: 'blue',
#       2: 81,
#       3: 'blue',
#       4: 'blue',
#       5: 'green',
#       6: 191,
#       7: 'blue',
#       8: 'blue',
#       9: 1},
#      'd': 'red',
#      'e': {1: 'orange',
#       2: -16,
#       3: {1: 'violet',
#        2: 63,
#        3: 'blue',
#        4: -40,
#        5: 119,
#        6: 22,
#        7: 'orange',
#        8: 'orange',
#        9: 'violet',
#        10: 'green'},
#       4: -30,
#       5: {'a': 'green',
#        'b': 'green',
#        'c': 172,
#        'd': 'yellow',
#        'e': 'yellow',
#        'f': 'red',
#        'g': 'yellow'},
#       6: 190,
#       7: 28,
#       8: {'a': 'orange',
#        'b': 51,
#        'c': 'red',
#        'd': -31,
#        'e': 'orange',
#        'f': 136},
#       9: 'orange',
#       10: 82},
#      'f': 0,
#      'g': 'blue',
#      'h': {'a': 'violet',
#       'b': 'yellow',
#       'c': {'a': 'green',
#        'b': 162,
#        'c': 13,
#        'd': 55,
#        'e': 'blue',
#        'f': 'red',
#        'g': 82,
#        'h': 'yellow',
#        'i': 'red',
#        'j': -36},
#       'd': -24,
#       'e': 'orange',
#       'f': 190}},
#     'j': 'violet'},
#    'e': {'a': {'a': 49, 'b': 189},
#     'b': 186,
#     'c': -11,
#     'd': {'a': {1: {1: 'orange', 2: 'green', 3: 'green', 4: 'red', 5: -25},
#       2: -16,
#       3: 104,
#       4: 177,
#       5: 'red'},
#      'b': 'blue',
#      'c': -14,
#      'd': 2,
#      'e': {1: 146,
#       2: {1: 32, 2: 'violet', 3: 'red', 4: 'orange', 5: -22},
#       3: 'blue',
#       4: 'violet',
#       5: 57,
#       6: {'a': 'red',
#        'b': -27,
#        'c': -13,
#        'd': 37,
#        'e': 12,
#        'f': 'orange',
#        'g': 'orange',
#        'h': 'green',
#        'i': 'red'},
#       7: 56,
#       8: -1,
#       9: 'red',
#       10: -25},
#      'f': 'green',
#      'g': 'red'},
#     'e': -13,
#     'f': {1: {'a': {1: 'blue', 2: 'blue'},
#       'b': 'yellow',
#       'c': 'yellow',
#       'd': 135,
#       'e': {'a': 'green', 'b': 144, 'c': -15, 'd': -32},
#       'f': 'violet'}},
#     'g': 144},
#    'f': 176,
#    'g': {1: {1: 88, 2: {1: 'blue', 2: 21, 3: 'yellow', 4: 'violet'}},
#     2: {1: 'red', 2: 169},
#     3: 'red'},
#    'h': 69},
#   2: {'a': 134,
#    'b': {1: 'orange',
#     2: -14,
#     3: {'a': 86,
#      'b': 'green',
#      'c': 16,
#      'd': {'a': -25,
#       'b': 113,
#       'c': 'orange',
#       'd': 71,
#       'e': 186,
#       'f': 'green',
#       'g': 27,
#       'h': 86,
#       'i': 'yellow'},
#      'e': 37,
#      'f': 'yellow',
#      'g': {1: 'yellow',
#       2: 'yellow',
#       3: {1: 'orange',
#        2: 'violet',
#        3: 'violet',
#        4: 'green',
#        5: 58,
#        6: 'orange'},
#       4: {1: 'orange',
#        2: 131,
#        3: 'red',
#        4: 'blue',
#        5: 'orange',
#        6: 183,
#        7: 82,
#        8: 'orange',
#        9: 'yellow',
#        10: 'blue'},
#       5: 49,
#       6: 'orange',
#       7: 'violet',
#       8: 'violet',
#       9: 'yellow',
#       10: 'orange'},
#      'h': 'orange'},
#     4: {1: 141,
#      2: 'violet',
#      3: 'red',
#      4: -24,
#      5: 18,
#      6: 103,
#      7: 88,
#      8: 169,
#      9: 75},
#     5: {1: 'yellow',
#      2: {1: 'green',
#       2: 55,
#       3: 92,
#       4: 'yellow',
#       5: 'orange',
#       6: 135,
#       7: {'a': -11,
#        'b': 129,
#        'c': 141,
#        'd': 'orange',
#        'e': 'green',
#        'f': 'green'},
#       8: 'violet'},
#      3: 14,
#      4: {1: {'a': 130},
#       2: {1: 'red',
#        2: 'violet',
#        3: 182,
#        4: 'blue',
#        5: 149,
#        6: 'orange',
#        7: -25,
#        8: 'blue',
#        9: 'blue'},
#       3: 61,
#       4: -18,
#       5: 'orange',
#       6: 14,
#       7: {'a': 135,
#        'b': 82,
#        'c': 23,
#        'd': 'yellow',
#        'e': 'red',
#        'f': 'red',
#        'g': 'orange',
#        'h': 89,
#        'i': 72,
#        'j': 'red'},
#       8: 'red'},
#      5: {1: 'red', 2: 'blue', 3: 'red', 4: 78, 5: 134, 6: 53, 7: 160},
#      6: -20,
#      7: 98,
#      8: {'a': 'violet',
#       'b': 'blue',
#       'c': {1: 7, 2: 99, 3: 186, 4: 'blue'},
#       'd': 'green',
#       'e': {1: 198,
#        2: 69,
#        3: 168,
#        4: 145,
#        5: -29,
#        6: 'red',
#        7: 'orange',
#        8: 'orange',
#        9: 'yellow'},
#       'f': 'yellow',
#       'g': 166,
#       'h': 10,
#       'i': 177,
#       'j': 184}},
#     6: 'green',
#     7: {'a': 'green',
#      'b': 'red',
#      'c': {'a': 'yellow',
#       'b': 'orange',
#       'c': 74,
#       'd': 34,
#       'e': 'orange',
#       'f': 124},
#      'd': -8,
#      'e': 'red',
#      'f': 161,
#      'g': 'yellow',
#      'h': 152,
#      'i': {1: 'blue',
#       2: 'red',
#       3: 'orange',
#       4: 'orange',
#       5: 'orange',
#       6: -38,
#       7: 'orange',
#       8: 'red'},
#      'j': -47},
#     8: 'yellow',
#     9: 'blue',
#     10: 75},
#    'c': {1: -33,
#     2: {'a': 'red',
#      'b': 122,
#      'c': 87,
#      'd': {'a': 'green',
#       'b': -24,
#       'c': 'violet',
#       'd': 43,
#       'e': 'orange',
#       'f': 'blue',
#       'g': 'blue',
#       'h': {'a': 'violet'},
#       'i': {1: 68, 2: 'blue'}},
#      'e': 102,
#      'f': 'green',
#      'g': 'violet',
#      'h': 'violet',
#      'i': 'violet',
#      'j': -28}},
#    'd': -12,
#    'e': {1: 'yellow',
#     2: 88,
#     3: 164,
#     4: {'a': {1: 20, 2: 'blue', 3: 'violet'},
#      'b': 80,
#      'c': 'yellow',
#      'd': 'yellow',
#      'e': 'red',
#      'f': 'green',
#      'g': -31},
#     5: {'a': 149,
#      'b': 'orange',
#      'c': 'green',
#      'd': -46,
#      'e': 'orange',
#      'f': {1: 160, 2: 83, 3: 'orange', 4: 'red', 5: 177, 6: -11}},
#     6: 'green',
#     7: {1: 156,
#      2: 'red',
#      3: {'a': {1: 152, 2: 107, 3: 130},
#       'b': {'a': 114, 'b': 38, 'c': 'yellow', 'd': 'blue'},
#       'c': 7,
#       'd': 'orange'},
#      4: {'a': 49, 'b': -34},
#      5: 34,
#      6: -32,
#      7: 'green'}},
#    'f': {'a': 164,
#     'b': {1: 'violet',
#      2: 'orange',
#      3: {1: 85,
#       2: {'a': 113,
#        'b': 'orange',
#        'c': 'green',
#        'd': 176,
#        'e': 'yellow',
#        'f': 'green',
#        'g': 166,
#        'h': 'violet',
#        'i': 'green'},
#       3: {1: 145, 2: 'green', 3: -7, 4: 'violet'}},
#      4: {'a': 'red',
#       'b': 'violet',
#       'c': -41,
#       'd': 79,
#       'e': {1: 'green', 2: 'green'},
#       'f': 148,
#       'g': 'blue',
#       'h': 'yellow',
#       'i': 20,
#       'j': 'blue'}},
#     'c': 98,
#     'd': 12,
#     'e': {'a': 'orange',
#      'b': {1: 93,
#       2: -1,
#       3: 'red',
#       4: {1: 39, 2: 'red', 3: 'green'},
#       5: 'green',
#       6: {1: 154, 2: 'blue', 3: 'orange', 4: 147, 5: 'orange', 6: 'yellow'},
#       7: 106,
#       8: {1: 'green', 2: 71, 3: -9},
#       9: -37},
#      'c': 'violet',
#      'd': {'a': 'orange',
#       'b': 'red',
#       'c': 'violet',
#       'd': 0,
#       'e': {1: 11},
#       'f': {'a': 45},
#       'g': 49},
#      'e': 39,
#      'f': 'blue',
#      'g': 'blue',
#      'h': -30,
#      'i': 176},
#     'f': {1: -34, 2: 'yellow'}},
#    'g': {1: 67,
#     2: {1: 'orange',
#      2: 109,
#      3: 114,
#      4: 32,
#      5: 'green',
#      6: 'green',
#      7: 'yellow',
#      8: {1: 'yellow',
#       2: 'orange',
#       3: -40,
#       4: {1: 'green',
#        2: 'orange',
#        3: 'yellow',
#        4: 187,
#        5: 3,
#        6: 'yellow',
#        7: 'violet',
#        8: 'orange',
#        9: 195,
#        10: 'yellow'},
#       5: 'blue',
#       6: 'yellow',
#       7: 'blue'}},
#     3: {1: 32, 2: {'a': 'red', 'b': 'blue', 'c': 43, 'd': 25}},
#     4: {'a': 24, 'b': 139, 'c': 'red'},
#     5: {'a': 153,
#      'b': 150,
#      'c': 143,
#      'd': 43,
#      'e': 'orange',
#      'f': 'green',
#      'g': {1: 'red', 2: 'red', 3: 'orange', 4: {1: 138, 2: 'green'}},
#      'h': {1: 'violet',
#       2: 'yellow',
#       3: 'green',
#       4: 159,
#       5: 165,
#       6: {'a': 'blue', 'b': 'violet'}}},
#     6: 'violet',
#     7: -12,
#     8: 'red',
#     9: {1: 'violet', 2: 'green'}},
#    'h': 'violet'},
#   3: {'a': {'a': {'a': -28},
#     'b': 82,
#     'c': {'a': 165,
#      'b': {1: -5,
#       2: {1: 'violet',
#        2: 'blue',
#        3: 'orange',
#        4: 'violet',
#        5: 3,
#        6: 'yellow',
#        7: 86,
#        8: 'orange',
#        9: 197,
#        10: 51},
#       3: 6,
#       4: 156,
#       5: 43,
#       6: 94,
#       7: 'blue',
#       8: {'a': -29, 'b': 89, 'c': 'orange', 'd': -41, 'e': 130, 'f': 'orange'},
#       9: 76},
#      'c': 147},
#     'd': 151,
#     'e': 7,
#     'f': 'blue',
#     'g': {1: 51,
#      2: -47,
#      3: 186,
#      4: {'a': 60, 'b': 'orange', 'c': 27, 'd': 32, 'e': 4, 'f': 'violet'},
#      5: {'a': 72,
#       'b': 'yellow',
#       'c': 'red',
#       'd': 17,
#       'e': 'blue',
#       'f': {1: 'red',
#        2: 'green',
#        3: 82,
#        4: -31,
#        5: 'blue',
#        6: -24,
#        7: 'yellow',
#        8: 'red',
#        9: 'violet'},
#       'g': 195,
#       'h': 0,
#       'i': 43,
#       'j': 'blue'},
#      6: {1: 'green'}},
#     'h': {'a': 'violet',
#      'b': 195,
#      'c': {'a': 'violet', 'b': 113, 'c': 'blue', 'd': 'yellow'},
#      'd': 'yellow',
#      'e': 153,
#      'f': 'green',
#      'g': 'yellow',
#      'h': {'a': {1: 'yellow', 2: 29, 3: 69},
#       'b': 164,
#       'c': 'red',
#       'd': 'orange',
#       'e': 'blue',
#       'f': {'a': 191, 'b': 61, 'c': 16},
#       'g': 'blue',
#       'h': 'green'},
#      'i': 'red',
#      'j': 'green'}},
#    'b': 180,
#    'c': 174,
#    'd': {1: 'violet', 2: 22, 3: 118},
#    'e': {'a': 'green',
#     'b': 'green',
#     'c': 'violet',
#     'd': 164,
#     'e': {1: {'a': 159},
#      2: {1: 'red',
#       2: -46,
#       3: {'a': 11},
#       4: 166,
#       5: 116,
#       6: {'a': 194, 'b': 27, 'c': -24, 'd': 91, 'e': -39},
#       7: -37,
#       8: 85,
#       9: {1: 'green'},
#       10: 61},
#      3: 'yellow',
#      4: {'a': 135},
#      5: {1: 'orange',
#       2: 'orange',
#       3: 128,
#       4: 'green',
#       5: -20,
#       6: 97,
#       7: {'a': 'blue',
#        'b': 'green',
#        'c': 195,
#        'd': 'violet',
#        'e': 108,
#        'f': 28,
#        'g': 51}}},
#     'f': -35,
#     'g': {'a': 'violet',
#      'b': 46,
#      'c': 151,
#      'd': 'yellow',
#      'e': 'red',
#      'f': {1: 'red'}},
#     'h': 'orange',
#     'i': 'orange'},
#    'f': {1: 'violet',
#     2: 'violet',
#     3: 'green',
#     4: {1: {1: {1: 66, 2: 'violet', 3: 'violet', 4: 'green', 5: 'green'}},
#      2: {1: 181,
#       2: 'yellow',
#       3: 167,
#       4: 134,
#       5: 'orange',
#       6: {'a': 'violet', 'b': 107, 'c': 'violet', 'd': -19, 'e': 'red'},
#       7: {'a': 'green', 'b': 'blue', 'c': 166, 'd': 'red', 'e': 0}},
#      3: 19,
#      4: -31,
#      5: 108}},
#    'g': {'a': {'a': 'violet',
#      'b': 'orange',
#      'c': 'blue',
#      'd': 'orange',
#      'e': {1: 'blue', 2: 'violet'},
#      'f': {'a': 'violet', 'b': 33},
#      'g': 'red'},
#     'b': 183,
#     'c': -7,
#     'd': 132},
#    'h': 79,
#    'i': {1: 'red',
#     2: 'red',
#     3: {1: 159},
#     4: {1: 139,
#      2: 'blue',
#      3: {'a': 106},
#      4: 48,
#      5: 117,
#      6: 164,
#      7: {1: 'blue',
#       2: 161,
#       3: 'green',
#       4: 174,
#       5: 'orange',
#       6: 152,
#       7: 'red',
#       8: 'orange',
#       9: {1: 'red', 2: 'yellow', 3: 'blue', 4: -43}},
#      8: 105,
#      9: 22,
#      10: 'green'},
#     5: {1: 110}},
#    'j': -45},
#   4: 153,
#   5: {'a': {'a': {1: {'a': 'yellow',
#       'b': 'yellow',
#       'c': 'violet',
#       'd': 'green',
#       'e': 'red',
#       'f': 58,
#       'g': -14,
#       'h': {'a': 148,
#        'b': 6,
#        'c': 62,
#        'd': 'yellow',
#        'e': 'blue',
#        'f': -1,
#        'g': 'violet'}},
#      2: 'violet',
#      3: 'yellow',
#      4: {'a': 'blue',
#       'b': 160,
#       'c': 195,
#       'd': {'a': -49,
#        'b': 'blue',
#        'c': 'orange',
#        'd': 'yellow',
#        'e': 'green',
#        'f': 'violet',
#        'g': 59,
#        'h': 'red',
#        'i': 46,
#        'j': -39},
#       'e': 4,
#       'f': 'orange',
#       'g': 'orange',
#       'h': 22,
#       'i': 38},
#      5: 'red',
#      6: {1: 'orange', 2: 'red', 3: 'yellow', 4: 34, 5: 101, 6: 'yellow'},
#      7: 40,
#      8: {1: 'orange',
#       2: {'a': 85,
#        'b': -13,
#        'c': 'red',
#        'd': -25,
#        'e': 148,
#        'f': 'orange',
#        'g': 62},
#       3: -47,
#       4: 34,
#       5: {'a': 'red', 'b': 34, 'c': 80, 'd': 100, 'e': 'violet'},
#       6: 58,
#       7: 185,
#       8: 'yellow',
#       9: 'orange',
#       10: {1: 'yellow',
#        2: 'green',
#        3: 'violet',
#        4: 84,
#        5: 'blue',
#        6: 'orange',
#        7: 13}},
#      9: 183},
#     'b': 'green',
#     'c': {1: 'violet', 2: -16},
#     'd': 'red',
#     'e': 'orange',
#     'f': 'yellow',
#     'g': {1: 'yellow',
#      2: 'yellow',
#      3: 'yellow',
#      4: 44,
#      5: 'orange',
#      6: 50,
#      7: 36,
#      8: {'a': 162,
#       'b': 31,
#       'c': 166,
#       'd': 112,
#       'e': 'green',
#       'f': -12,
#       'g': 'blue',
#       'h': 92}},
#     'h': 'blue',
#     'i': {1: 'yellow',
#      2: 'violet',
#      3: {1: 19, 2: 'red', 3: {1: 'violet', 2: 'violet', 3: 195}},
#      4: {1: 'yellow', 2: {1: 106}, 3: 'red', 4: 'orange', 5: 'blue'},
#      5: 178,
#      6: {'a': 104,
#       'b': 'green',
#       'c': 'yellow',
#       'd': 'red',
#       'e': 'violet',
#       'f': 'blue',
#       'g': 0,
#       'h': {'a': 'blue', 'b': 84, 'c': -47},
#       'i': 'red'},
#      7: 105},
#     'j': {1: -2,
#      2: 'red',
#      3: 'yellow',
#      4: 176,
#      5: -24,
#      6: 140,
#      7: 'blue',
#      8: 'yellow',
#      9: 155,
#      10: {'a': {'a': 'green', 'b': 3},
#       'b': 'red',
#       'c': 'violet',
#       'd': -16,
#       'e': -28}}}},
#   6: {'a': {'a': {'a': 'orange',
#      'b': 'green',
#      'c': 92,
#      'd': {1: 186, 2: 122},
#      'e': {'a': {1: 'blue', 2: 'yellow', 3: 'orange'},
#       'b': 'green',
#       'c': {1: 159, 2: 'blue', 3: 'violet', 4: 'red', 5: 61, 6: 3},
#       'd': 'green',
#       'e': 'violet',
#       'f': 130,
#       'g': 132,
#       'h': 'red'},
#      'f': 'yellow'}},
#    'b': 'violet',
#    'c': {1: 156},
#    'd': {'a': {'a': {1: 'green'},
#      'b': {'a': 22},
#      'c': {'a': 'blue', 'b': 91, 'c': 78, 'd': 49, 'e': 'red', 'f': 14},
#      'd': {'a': 'blue'}},
#     'b': 154,
#     'c': -6,
#     'd': 'orange',
#     'e': {'a': 127,
#      'b': 41,
#      'c': 'orange',
#      'd': {1: 36,
#       2: 61,
#       3: 178,
#       4: 'yellow',
#       5: 'green',
#       6: 'red',
#       7: 'violet',
#       8: {'a': 'yellow',
#        'b': 'yellow',
#        'c': 0,
#        'd': 'red',
#        'e': -18,
#        'f': 'yellow',
#        'g': 6,
#        'h': 'yellow'},
#       9: 162}},
#     'f': {'a': 170}},
#    'e': 7,
#    'f': -33,
#    'g': {1: 'yellow', 2: 'violet'}},
#   7: 'blue',
#   8: 82},
#  'd': {1: {1: {1: 42,
#     2: 67,
#     3: {'a': 'orange',
#      'b': 'green',
#      'c': {'a': 'orange',
#       'b': 'yellow',
#       'c': 'blue',
#       'd': 120,
#       'e': 'orange',
#       'f': 'yellow',
#       'g': {1: 162, 2: 'orange', 3: 2},
#       'h': {1: 172,
#        2: 'orange',
#        3: 171,
#        4: -40,
#        5: 139,
#        6: 161,
#        7: 'yellow',
#        8: 197},
#       'i': 'orange'},
#      'd': {'a': -26,
#       'b': 105,
#       'c': 'green',
#       'd': 52,
#       'e': 'orange',
#       'f': 'yellow',
#       'g': {1: 68, 2: 162, 3: 'orange', 4: 'red'}},
#      'e': 'yellow',
#      'f': 65,
#      'g': {'a': 6,
#       'b': 56,
#       'c': 193,
#       'd': 'violet',
#       'e': 33,
#       'f': {'a': 'green', 'b': 161, 'c': -46},
#       'g': 146,
#       'h': 89,
#       'i': 149},
#      'h': -21},
#     4: {1: {1: 'yellow', 2: 31, 3: -4},
#      2: 'red',
#      3: -27,
#      4: 21,
#      5: {'a': 'orange',
#       'b': 60,
#       'c': 'orange',
#       'd': {'a': 'yellow',
#        'b': 134,
#        'c': 'green',
#        'd': 149,
#        'e': 'yellow',
#        'f': 'yellow',
#        'g': 'violet'},
#       'e': {'a': -1,
#        'b': 'green',
#        'c': 'violet',
#        'd': 'violet',
#        'e': -25,
#        'f': 'orange',
#        'g': 'violet',
#        'h': 'blue',
#        'i': 'yellow'},
#       'f': 'blue',
#       'g': 'orange'},
#      6: 'violet',
#      7: {1: 66, 2: 'green', 3: 25, 4: 106, 5: 'red', 6: 'orange'},
#      8: {'a': {'a': 95,
#        'b': 87,
#        'c': 176,
#        'd': 'red',
#        'e': 'orange',
#        'f': 71,
#        'g': 195,
#        'h': 179,
#        'i': 'violet'},
#       'b': 14},
#      9: 55},
#     5: 'blue'},
#    2: {1: {1: 62,
#      2: 'violet',
#      3: 58,
#      4: {1: -42,
#       2: 'orange',
#       3: {'a': 'orange',
#        'b': 'green',
#        'c': 163,
#        'd': 'green',
#        'e': 186,
#        'f': -8,
#        'g': 'orange',
#        'h': -9,
#        'i': 'orange',
#        'j': 100},
#       4: 'red',
#       5: 12,
#       6: 'orange',
#       7: -3,
#       8: 162,
#       9: 'green'},
#      5: 'violet',
#      6: 94,
#      7: 'orange',
#      8: 41,
#      9: 58,
#      10: 'violet'},
#     2: {1: {1: 'green', 2: 'green', 3: 'red'},
#      2: 'red',
#      3: 128,
#      4: 'blue',
#      5: 'yellow',
#      6: 'yellow',
#      7: {'a': 193,
#       'b': 13,
#       'c': 'violet',
#       'd': {1: 'orange', 2: 134},
#       'e': 'yellow',
#       'f': {'a': 83, 'b': 122, 'c': 26, 'd': 'orange', 'e': -33},
#       'g': 'yellow',
#       'h': -39,
#       'i': 'orange',
#       'j': {1: 'green', 2: 45, 3: 195, 4: 123, 5: 50, 6: 61}},
#      8: 'blue',
#      9: 46,
#      10: 'yellow'},
#     3: 'yellow',
#     4: 'yellow',
#     5: 30,
#     6: {1: 158,
#      2: {'a': 68, 'b': 122, 'c': 'green'},
#      3: {'a': 'green',
#       'b': 115,
#       'c': 'orange',
#       'd': 180,
#       'e': 95,
#       'f': 'yellow'},
#      4: {1: 194,
#       2: -29,
#       3: 'orange',
#       4: 'violet',
#       5: {'a': 193,
#        'b': 'yellow',
#        'c': 'blue',
#        'd': 'green',
#        'e': 173,
#        'f': 186,
#        'g': 'green',
#        'h': 'green',
#        'i': 'red',
#        'j': 'blue'},
#       6: 135},
#      5: 'violet'}},
#    3: 'yellow',
#    4: 144,
#    5: {1: 'violet',
#     2: 'red',
#     3: {'a': {1: 121}, 'b': 134},
#     4: {'a': -23, 'b': 'violet'},
#     5: {1: 7},
#     6: {1: 101,
#      2: 181,
#      3: 'yellow',
#      4: {'a': 56, 'b': 'green', 'c': 'green', 'd': 175, 'e': 'violet'}}},
#    6: 'violet',
#    7: {'a': {'a': -49,
#      'b': {1: {1: 'orange',
#        2: 'yellow',
#        3: -17,
#        4: 'orange',
#        5: -11,
#        6: -41,
#        7: 'red',
#        8: 32},
#       2: 'blue',
#       3: 46,
#       4: {'a': 'yellow', 'b': 'violet'}},
#      'c': -42,
#      'd': 'red',
#      'e': 'green',
#      'f': {1: 'violet', 2: 'violet', 3: -11}},
#     'b': {1: 'orange',
#      2: {'a': -5,
#       'b': 39,
#       'c': 'violet',
#       'd': {1: 122, 2: 129, 3: 'violet', 4: 'orange'},
#       'e': 62},
#      3: 'green'},
#     'c': 'green'}}},
#  'e': {1: {1: {'a': {'a': {1: 120, 2: 169, 3: 'green', 4: 'red', 5: 'orange'},
#      'b': 'red'},
#     'b': {1: 'yellow'},
#     'c': 23,
#     'd': 'red',
#     'e': 86,
#     'f': -19,
#     'g': 'yellow'},
#    2: {'a': {1: 2},
#     'b': {'a': 'yellow',
#      'b': 'blue',
#      'c': 47,
#      'd': 'green',
#      'e': 59,
#      'f': {1: 'violet', 2: 43, 3: 168, 4: 78},
#      'g': 'orange',
#      'h': 'red'},
#     'c': 'green',
#     'd': {'a': 'violet'},
#     'e': -47,
#     'f': {1: {'a': 77,
#       'b': 147,
#       'c': 'green',
#       'd': 49,
#       'e': {1: 82,
#        2: -41,
#        3: 2,
#        4: 'red',
#        5: 'violet',
#        6: 'orange',
#        7: 'yellow'},
#       'f': 'blue',
#       'g': 'orange'},
#      2: -1,
#      3: 142,
#      4: 136,
#      5: {1: 'green', 2: 'red', 3: 166, 4: -21},
#      6: 'blue',
#      7: 'orange',
#      8: {'a': 38}},
#     'g': 'orange',
#     'h': 'orange'},
#    3: 'orange',
#    4: 'yellow'},
#   2: 'green',
#   3: -22,
#   4: {1: 37,
#    2: {1: 4,
#     2: -40,
#     3: {1: 'red',
#      2: 'yellow',
#      3: {1: 'yellow',
#       2: 177,
#       3: 'red',
#       4: 'blue',
#       5: 139,
#       6: {1: 55,
#        2: 13,
#        3: 'yellow',
#        4: 'violet',
#        5: -21,
#        6: 140,
#        7: 'yellow',
#        8: 117},
#       7: 'blue',
#       8: 'blue',
#       9: 106},
#      4: 'blue',
#      5: {'a': 23}},
#     4: 183,
#     5: 92,
#     6: 'orange',
#     7: 'green'},
#    3: 'orange'},
#   5: -5},
#  'f': {'a': {1: 'blue',
#    2: {'a': {1: {'a': {'a': 'yellow',
#        'b': 'green',
#        'c': 78,
#        'd': 'green',
#        'e': -46,
#        'f': 'red',
#        'g': 189,
#        'h': 59,
#        'i': 'red'},
#       'b': 'yellow',
#       'c': 71,
#       'd': {'a': 'orange',
#        'b': 189,
#        'c': 'violet',
#        'd': 21,
#        'e': 'violet',
#        'f': 71},
#       'e': {'a': 'yellow'},
#       'f': 15},
#      2: 'green',
#      3: 150,
#      4: 'yellow'},
#     'b': 101,
#     'c': -21,
#     'd': 'blue',
#     'e': {'a': 'blue',
#      'b': {1: 184, 2: 'green', 3: 'blue', 4: -38, 5: 193, 6: 75, 7: 156},
#      'c': 'yellow',
#      'd': 96,
#      'e': 131,
#      'f': {'a': {'a': -23, 'b': 'yellow', 'c': 'red', 'd': -37},
#       'b': 'blue',
#       'c': 0,
#       'd': 61,
#       'e': 177,
#       'f': 78,
#       'g': 149},
#      'g': {'a': {'a': 162,
#        'b': -7,
#        'c': 100,
#        'd': -14,
#        'e': 53,
#        'f': 'orange'},
#       'b': 'yellow',
#       'c': 70,
#       'd': 'green',
#       'e': 'yellow',
#       'f': 149}},
#     'f': 'blue'},
#    3: 'green',
#    4: {1: {1: -10, 2: {'a': 99, 'b': 'green', 'c': 61}},
#     2: 'violet',
#     3: {1: 'blue', 2: -41},
#     4: 54,
#     5: {1: 194,
#      2: 146,
#      3: 'green',
#      4: 90,
#      5: 'violet',
#      6: 'violet',
#      7: -5,
#      8: 'red'},
#     6: {'a': 'green',
#      'b': 'green',
#      'c': {1: 96, 2: 127, 3: 29},
#      'd': {'a': 'blue',
#       'b': 'orange',
#       'c': 94,
#       'd': {1: 'yellow',
#        2: 10,
#        3: 'blue',
#        4: 86,
#        5: 44,
#        6: 'violet',
#        7: 'red',
#        8: 'red'},
#       'e': 'blue',
#       'f': 'green',
#       'g': 'red',
#       'h': {'a': 89,
#        'b': 148,
#        'c': 'blue',
#        'd': 91,
#        'e': 'red',
#        'f': 52,
#        'g': 197}},
#      'e': 114,
#      'f': {'a': 'blue',
#       'b': -49,
#       'c': 'red',
#       'd': 'orange',
#       'e': 'green',
#       'f': 8,
#       'g': -34,
#       'h': 92,
#       'i': 125,
#       'j': 40},
#      'g': 'yellow',
#      'h': 'blue',
#      'i': -30},
#     7: {'a': 154, 'b': 100}}},
#   'b': 118,
#   'c': {'a': 95},
#   'd': {'a': 'yellow',
#    'b': {'a': {1: 109,
#      2: 28,
#      3: 52,
#      4: {1: 118, 2: 'violet'},
#      5: {'a': 'blue'},
#      6: 10,
#      7: 163,
#      8: 'green',
#      9: -21},
#     'b': 'blue',
#     'c': 'green',
#     'd': 'green',
#     'e': {1: 83,
#      2: 'red',
#      3: {1: 'green', 2: {'a': 'violet'}, 3: 126, 4: 105, 5: 86},
#      4: {1: {1: 'blue', 2: -40, 3: 148, 4: 'blue'},
#       2: 168,
#       3: 'red',
#       4: 'green',
#       5: {1: 'green', 2: 41, 3: 93, 4: 'red', 5: -19},
#       6: 32,
#       7: 'violet',
#       8: 'violet',
#       9: 'blue',
#       10: 'yellow'},
#      5: {'a': 'yellow', 'b': 'green'},
#      6: {1: 85, 2: 164},
#      7: 17,
#      8: 60,
#      9: 66,
#      10: {'a': 'yellow', 'b': -10, 'c': 'yellow', 'd': 'yellow'}},
#     'f': 'yellow',
#     'g': {'a': 'green',
#      'b': {1: {'a': 100, 'b': 'yellow'},
#       2: 63,
#       3: 41,
#       4: 168,
#       5: 152,
#       6: 'yellow',
#       7: 198,
#       8: -14,
#       9: 30,
#       10: 103},
#      'c': {1: 'yellow', 2: 119, 3: 127},
#      'd': 'violet',
#      'e': -22,
#      'f': {1: 'blue',
#       2: 135,
#       3: 'yellow',
#       4: 'green',
#       5: 'yellow',
#       6: {1: 'yellow', 2: 35, 3: 91, 4: 182}},
#      'g': 1},
#     'h': {1: 'violet', 2: 'violet'},
#     'i': {'a': {1: {'a': 'yellow'},
#       2: 'green',
#       3: 'orange',
#       4: 50,
#       5: 117,
#       6: 94,
#       7: 'red',
#       8: 89},
#      'b': 'red',
#      'c': 'green'}},
#    'c': {'a': 'violet', 'b': 'violet'}},
#   'e': {'a': {'a': -23,
#     'b': 93,
#     'c': 68,
#     'd': 'orange',
#     'e': {'a': 'yellow',
#      'b': 27,
#      'c': 'violet',
#      'd': {'a': {1: 'violet', 2: 195, 3: 77, 4: -13, 5: 'green', 6: 'red'},
#       'b': 'blue',
#       'c': -48,
#       'd': 'red'},
#      'e': 'green',
#      'f': 197,
#      'g': -37,
#      'h': {1: -13, 2: 'green'}},
#     'f': {'a': 'green', 'b': -4}},
#    'b': {'a': 171,
#     'b': 'orange',
#     'c': 68,
#     'd': 'violet',
#     'e': 'red',
#     'f': {'a': {1: 'green'}, 'b': 148, 'c': 22},
#     'g': -30},
#    'c': {1: {1: 'violet',
#      2: 'blue',
#      3: 'orange',
#      4: {'a': {1: 'blue',
#        2: 'blue',
#        3: 'orange',
#        4: 144,
#        5: 130,
#        6: 'red',
#        7: 'violet',
#        8: 'red',
#        9: 112},
#       'b': 'blue',
#       'c': 66,
#       'd': 192,
#       'e': 42},
#      5: 'orange',
#      6: {1: 'orange', 2: 4, 3: 'violet', 4: -47, 5: 'orange'},
#      7: {1: 'violet',
#       2: 'yellow',
#       3: 54,
#       4: {'a': 'yellow', 'b': 'red', 'c': 47},
#       5: {'a': 'violet'},
#       6: 151,
#       7: -30,
#       8: 'orange',
#       9: 'red'},
#      8: -31,
#      9: 'blue'},
#     2: 135,
#     3: {'a': {1: 5, 2: 117},
#      'b': 15,
#      'c': {'a': 142,
#       'b': 'yellow',
#       'c': 'red',
#       'd': 'orange',
#       'e': 134,
#       'f': {'a': 'violet', 'b': 'yellow', 'c': 'orange'},
#       'g': 122,
#       'h': 'violet',
#       'i': 107,
#       'j': 189},
#      'd': 119,
#      'e': 'red',
#      'f': {'a': 187,
#       'b': 36,
#       'c': 174,
#       'd': 80,
#       'e': 'blue',
#       'f': 188,
#       'g': 'violet'},
#      'g': {1: 157,
#       2: 135,
#       3: 122,
#       4: -34,
#       5: 168,
#       6: 'green',
#       7: -19,
#       8: 13,
#       9: 64},
#      'h': 109,
#      'i': -10,
#      'j': 189},
#     4: 60,
#     5: 'orange',
#     6: 146,
#     7: {'a': {'a': 63},
#      'b': -29,
#      'c': 67,
#      'd': 'green',
#      'e': -8,
#      'f': {1: 'violet', 2: 'green', 3: 'orange'},
#      'g': 'orange',
#      'h': {1: 'blue',
#       2: 'yellow',
#       3: 'red',
#       4: 'blue',
#       5: {1: 'yellow', 2: 189, 3: 'orange', 4: 'green'},
#       6: 'orange',
#       7: 'violet'}},
#     8: {'a': -45,
#      'b': {'a': 76,
#       'b': 154,
#       'c': 'orange',
#       'd': 'yellow',
#       'e': 112,
#       'f': -3,
#       'g': {1: 'orange', 2: 'red', 3: 'yellow', 4: -26, 5: 'orange'},
#       'h': 137,
#       'i': 'yellow',
#       'j': 93},
#      'c': 'red',
#      'd': {'a': 174, 'b': 'green', 'c': 48, 'd': 189, 'e': 'violet'},
#      'e': 'violet',
#      'f': {1: 69,
#       2: 'red',
#       3: {'a': 'green', 'b': 'blue'},
#       4: 'red',
#       5: {'a': 85}},
#      'g': {1: 45,
#       2: 'green',
#       3: -24,
#       4: -7,
#       5: {'a': 67, 'b': 'red'},
#       6: 'orange',
#       7: 188,
#       8: {1: 'red', 2: 'blue', 3: 'red'},
#       9: 47,
#       10: 133}},
#     9: {'a': 45,
#      'b': 'green',
#      'c': {'a': -22,
#       'b': 3,
#       'c': 'red',
#       'd': {'a': 'yellow',
#        'b': 165,
#        'c': 52,
#        'd': 'blue',
#        'e': 185,
#        'f': 'yellow'},
#       'e': 'violet'},
#      'd': 'blue',
#      'e': 'violet'}},
#    'd': {1: -48},
#    'e': {1: {'a': {'a': {'a': 'blue',
#        'b': 148,
#        'c': 'violet',
#        'd': 164,
#        'e': 122,
#        'f': 190,
#        'g': 'blue',
#        'h': -1,
#        'i': -37,
#        'j': 54}},
#      'b': {1: {'a': 158},
#       2: 'blue',
#       3: 26,
#       4: {'a': 64,
#        'b': 'blue',
#        'c': 'green',
#        'd': 'blue',
#        'e': 'violet',
#        'f': 'green',
#        'g': 36},
#       5: 'violet',
#       6: 125,
#       7: 'orange'},
#      'c': 171,
#      'd': 'violet',
#      'e': {'a': 'violet'}},
#     2: 'yellow',
#     3: {'a': 'orange',
#      'b': {'a': 108, 'b': {1: 'red', 2: -48}},
#      'c': {'a': 191,
#       'b': 67,
#       'c': 121,
#       'd': -25,
#       'e': -46,
#       'f': 'blue',
#       'g': 'blue'}},
#     4: {'a': -34,
#      'b': 'yellow',
#      'c': 'green',
#      'd': 37,
#      'e': 116,
#      'f': {'a': 105,
#       'b': 27,
#       'c': 'red',
#       'd': 'red',
#       'e': -3,
#       'f': 'violet',
#       'g': 189,
#       'h': 'green'},
#      'g': 59},
#     5: 'red',
#     6: {1: 'yellow',
#      2: 152,
#      3: {'a': {1: 164, 2: 155, 3: 'green', 4: 'yellow'},
#       'b': 32,
#       'c': 'violet',
#       'd': 79,
#       'e': 'red',
#       'f': 'green',
#       'g': 'green',
#       'h': {'a': 'orange',
#        'b': -43,
#        'c': 53,
#        'd': 'violet',
#        'e': 'blue',
#        'f': 'orange'},
#       'i': 23},
#      4: 'red',
#      5: 'violet',
#      6: -37,
#      7: {1: {1: 'green', 2: 'violet', 3: 131, 4: -18, 5: 'green'},
#       2: 48,
#       3: 6,
#       4: 'red',
#       5: 83},
#      8: 152,
#      9: 181,
#      10: 75},
#     7: {'a': 170,
#      'b': 13,
#      'c': 'red',
#      'd': {'a': 'yellow', 'b': 'blue'},
#      'e': {1: 116, 2: 100, 3: 'red', 4: {'a': 156}, 5: 'green'},
#      'f': {'a': 'orange',
#       'b': 'green',
#       'c': 'orange',
#       'd': {1: 'orange',
#        2: 'orange',
#        3: 98,
#        4: -13,
#        5: 'yellow',
#        6: 183,
#        7: 193,
#        8: 'green'},
#       'e': -45,
#       'f': 'green'},
#      'g': {1: 28, 2: 59, 3: 'violet', 4: 'violet', 5: 144}},
#     8: 128,
#     9: {1: 'green'}},
#    'f': {1: 162,
#     2: {'a': 'blue', 'b': 'blue', 'c': {1: -30, 2: 'violet'}, 'd': 83},
#     3: 'blue'},
#    'g': {'a': {1: 'green',
#      2: 'green',
#      3: {'a': 'violet', 'b': 115},
#      4: {'a': 198,
#       'b': 'violet',
#       'c': 'yellow',
#       'd': 'violet',
#       'e': 59,
#       'f': 'violet',
#       'g': 69,
#       'h': -38,
#       'i': -12},
#      5: 35},
#     'b': 'blue',
#     'c': 28,
#     'd': {'a': 'green',
#      'b': 160,
#      'c': 'red',
#      'd': {1: 'violet', 2: -49, 3: 'yellow', 4: {1: 46, 2: 'blue', 3: 196}},
#      'e': {1: -20, 2: 'orange', 3: 'green', 4: 116, 5: 'yellow', 6: -21}},
#     'e': 77},
#    'h': 'orange',
#    'i': 'green'},
#   'f': 0,
#   'g': 'green',
#   'h': {'a': 138},
#   'i': 'violet',
#   'j': {'a': 'violet',
#    'b': {1: 14,
#     2: {'a': {'a': 182,
#       'b': 'green',
#       'c': 'blue',
#       'd': 'yellow',
#       'e': 59,
#       'f': 'yellow',
#       'g': 93,
#       'h': 'yellow',
#       'i': 147},
#      'b': -14,
#      'c': 'violet',
#      'd': 58,
#      'e': 82,
#      'f': {'a': 154},
#      'g': 'red',
#      'h': {'a': {'a': 'orange',
#        'b': 'yellow',
#        'c': 142,
#        'd': 181,
#        'e': 27,
#        'f': 'yellow',
#        'g': 44,
#        'h': 195}},
#      'i': 90},
#     3: 'orange',
#     4: {'a': 'blue', 'b': -11},
#     5: {1: 'yellow',
#      2: {1: 38, 2: -34, 3: 'orange', 4: 57},
#      3: 'orange',
#      4: 98,
#      5: 'violet',
#      6: 'violet',
#      7: {'a': 134},
#      8: {1: 24, 2: 'blue', 3: 'blue', 4: 172, 5: 114},
#      9: 10},
#     6: {1: {'a': {1: 'yellow', 2: 'green'}},
#      2: 166,
#      3: 'blue',
#      4: {1: 'blue',
#       2: {'a': 'green',
#        'b': 'green',
#        'c': -6,
#        'd': 'green',
#        'e': 'blue',
#        'f': 50},
#       3: -44,
#       4: {'a': 'yellow',
#        'b': 'green',
#        'c': 'orange',
#        'd': -27,
#        'e': 'violet',
#        'f': 'violet',
#        'g': 30,
#        'h': 146,
#        'i': 'violet',
#        'j': 33},
#       5: 'blue',
#       6: 'red',
#       7: 'violet',
#       8: 6}},
#     7: 113},
#    'c': 'red',
#    'd': 'blue',
#    'e': {'a': 113,
#     'b': {'a': 135, 'b': 'yellow', 'c': -9, 'd': 81, 'e': 'yellow'},
#     'c': {1: 'blue', 2: 'violet'},
#     'd': {'a': -19,
#      'b': 'orange',
#      'c': 195,
#      'd': -14,
#      'e': 189,
#      'f': 'green',
#      'g': 45,
#      'h': 'yellow',
#      'i': 'violet',
#      'j': {'a': 1,
#       'b': 'green',
#       'c': 'red',
#       'd': 'violet',
#       'e': 'green',
#       'f': 192,
#       'g': -19,
#       'h': 106,
#       'i': 'green'}},
#     'e': {'a': 70},
#     'f': 75},
#    'f': {1: 'green'},
#    'g': {'a': {1: 'green',
#      2: 86,
#      3: 28,
#      4: {1: 55,
#       2: 127,
#       3: 'blue',
#       4: 172,
#       5: 'green',
#       6: 83,
#       7: 'green',
#       8: 'violet',
#       9: {'a': 53},
#       10: 'blue'},
#      5: {'a': 181, 'b': 57},
#      6: {1: 28, 2: 'violet'},
#      7: 'red',
#      8: {'a': 138},
#      9: 198},
#     'b': {'a': {1: 'green',
#       2: 'green',
#       3: 170,
#       4: 'blue',
#       5: -40,
#       6: 'yellow',
#       7: 'red',
#       8: 10},
#      'b': {1: {1: 'green',
#        2: 'yellow',
#        3: 2,
#        4: 'violet',
#        5: -30,
#        6: 'yellow',
#        7: 'red',
#        8: -40,
#        9: 'orange',
#        10: 'violet'},
#       2: 'red',
#       3: 58,
#       4: 165,
#       5: 'red'},
#      'c': 86,
#      'd': 13},
#     'c': {1: {'a': 'green',
#       'b': {'a': 68,
#        'b': 'green',
#        'c': 'green',
#        'd': 'orange',
#        'e': 'orange',
#        'f': 13,
#        'g': 'green',
#        'h': 161},
#       'c': 65,
#       'd': -38,
#       'e': 'violet'},
#      2: 'blue',
#      3: {'a': 40,
#       'b': 117,
#       'c': 'red',
#       'd': 'green',
#       'e': 73,
#       'f': 170,
#       'g': 178,
#       'h': 'yellow'},
#      4: 'yellow',
#      5: 188},
#     'd': 'yellow',
#     'e': {'a': 125,
#      'b': {1: 'green', 2: -38, 3: 'yellow'},
#      'c': {1: 'green', 2: 'yellow'},
#      'd': 183,
#      'e': 'red',
#      'f': 'blue',
#      'g': 71,
#      'h': 12,
#      'i': 'blue',
#      'j': 74},
#     'f': 'violet',
#     'g': {'a': 63},
#     'h': {'a': -21}},
#    'h': 113,
#    'i': {1: {1: 'yellow',
#      2: 'yellow',
#      3: 'red',
#      4: {'a': 'yellow',
#       'b': 'orange',
#       'c': 124,
#       'd': 'violet',
#       'e': -5,
#       'f': 149,
#       'g': 'violet'},
#      5: -16,
#      6: 9},
#     2: 'violet',
#     3: -43,
#     4: {'a': 52, 'b': 179, 'c': 9, 'd': 74},
#     5: 'violet',
#     6: {1: {'a': 82,
#       'b': {1: 'yellow',
#        2: 'blue',
#        3: 'blue',
#        4: 29,
#        5: 'orange',
#        6: 'green',
#        7: 'green',
#        8: 0},
#       'c': {'a': 'violet',
#        'b': 48,
#        'c': 37,
#        'd': 'yellow',
#        'e': 'green',
#        'f': 'green',
#        'g': 12,
#        'h': 'violet',
#        'i': 'red',
#        'j': 'blue'},
#       'd': 'green',
#       'e': -30,
#       'f': 'orange',
#       'g': 128,
#       'h': 58,
#       'i': 91,
#       'j': 49},
#      2: {1: 181,
#       2: 'red',
#       3: 'green',
#       4: 'violet',
#       5: 'red',
#       6: 'green',
#       7: 'orange',
#       8: {'a': 'yellow',
#        'b': 128,
#        'c': 24,
#        'd': 'green',
#        'e': 'green',
#        'f': 162,
#        'g': 'red',
#        'h': 194,
#        'i': 'violet'},
#       9: 191},
#      3: 'red',
#      4: 'violet',
#      5: 'yellow',
#      6: 'red'},
#     7: 141,
#     8: 123}}}}

# %%
import re

regex = re.compile(r'-?[0-9]+')

def find_sum(input):
  sum = 0
  for mo in regex.finditer(input):
    #print(mo.group(0))
    sum += int(mo.group(0))
  return sum

# %%
#check for decimals

regex2 = re.compile(r'\.[0-9]+')

for mo in regex2.finditer(input[100:200]):
  print(mo.group(0))

# %%
input[100:200]
# Out:
# '"],"d":"red","f":-19},{"e":-47,"a":[2],"d":{"a":"violet"},"c":"green","h":"orange","b":{"e":59,"a":"'

# %%
print(find_sum(input))
# Out:
# 111754

# %% [markdown]
# https://adventofcode.com/2015/day/12#part2

# %%
def sum_non_red(ob):
  if isinstance(ob, dict):
    if 'red' in ob.values():
      return 0
    else:
      return sum(map(sum_non_red, ob.keys())) + sum(map(sum_non_red, ob.values()))
  elif isinstance(ob, list):
    return sum(map(sum_non_red, ob))
  elif isinstance(ob, str):
    return 0
  elif isinstance(ob, int):
    return ob
  else:
    raise ValueError()

sum_non_red(json.loads(input))
# Out:
# 65402
