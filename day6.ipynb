# %%
input = '''toggle 461,550 through 564,900
turn off 370,39 through 425,839
turn off 464,858 through 833,915
turn off 812,389 through 865,874
turn on 599,989 through 806,993
turn on 376,415 through 768,548
turn on 606,361 through 892,600
turn off 448,208 through 645,684
toggle 50,472 through 452,788
toggle 205,417 through 703,826
toggle 533,331 through 906,873
toggle 857,493 through 989,970
turn off 631,950 through 894,975
turn off 387,19 through 720,700
turn off 511,843 through 581,945
toggle 514,557 through 662,883
turn off 269,809 through 876,847
turn off 149,517 through 716,777
turn off 994,939 through 998,988
toggle 467,662 through 555,957
turn on 952,417 through 954,845
turn on 565,226 through 944,880
turn on 214,319 through 805,722
toggle 532,276 through 636,847
toggle 619,80 through 689,507
turn on 390,706 through 884,722
toggle 17,634 through 537,766
toggle 706,440 through 834,441
toggle 318,207 through 499,530
toggle 698,185 through 830,343
toggle 566,679 through 744,716
toggle 347,482 through 959,482
toggle 39,799 through 981,872
turn on 583,543 through 846,710
turn off 367,664 through 595,872
turn on 805,439 through 964,995
toggle 209,584 through 513,802
turn off 106,497 through 266,770
turn on 975,2 through 984,623
turn off 316,684 through 369,876
turn off 30,309 through 259,554
turn off 399,680 through 861,942
toggle 227,740 through 850,829
turn on 386,603 through 552,879
turn off 703,795 through 791,963
turn off 573,803 through 996,878
turn off 993,939 through 997,951
turn on 809,221 through 869,723
turn off 38,720 through 682,751
turn off 318,732 through 720,976
toggle 88,459 through 392,654
turn off 865,654 through 911,956
toggle 264,284 through 857,956
turn off 281,776 through 610,797
toggle 492,660 through 647,910
turn off 879,703 through 925,981
turn off 772,414 through 974,518
turn on 694,41 through 755,96
turn on 452,406 through 885,881
turn off 107,905 through 497,910
turn off 647,222 through 910,532
turn on 679,40 through 845,358
turn off 144,205 through 556,362
turn on 871,804 through 962,878
turn on 545,676 through 545,929
turn off 316,716 through 413,941
toggle 488,826 through 755,971
toggle 957,832 through 976,992
toggle 857,770 through 905,964
toggle 319,198 through 787,673
turn on 832,813 through 863,844
turn on 818,296 through 818,681
turn on 71,699 through 91,960
turn off 838,578 through 967,928
toggle 440,856 through 507,942
toggle 121,970 through 151,974
toggle 391,192 through 659,751
turn on 78,210 through 681,419
turn on 324,591 through 593,939
toggle 159,366 through 249,760
turn off 617,167 through 954,601
toggle 484,607 through 733,657
turn on 587,96 through 888,819
turn off 680,984 through 941,991
turn on 800,512 through 968,691
turn off 123,588 through 853,603
turn on 1,862 through 507,912
turn on 699,839 through 973,878
turn off 848,89 through 887,893
toggle 344,353 through 462,403
turn on 780,731 through 841,760
toggle 693,973 through 847,984
toggle 989,936 through 996,958
toggle 168,475 through 206,963
turn on 742,683 through 769,845
toggle 768,116 through 987,396
turn on 190,364 through 617,526
turn off 470,266 through 530,839
toggle 122,497 through 969,645
turn off 492,432 through 827,790
turn on 505,636 through 957,820
turn on 295,476 through 698,958
toggle 63,298 through 202,396
turn on 157,315 through 412,939
turn off 69,789 through 134,837
turn off 678,335 through 896,541
toggle 140,516 through 842,668
turn off 697,585 through 712,668
toggle 507,832 through 578,949
turn on 678,279 through 886,621
toggle 449,744 through 826,910
turn off 835,354 through 921,741
toggle 924,878 through 985,952
turn on 666,503 through 922,905
turn on 947,453 through 961,587
toggle 525,190 through 795,654
turn off 62,320 through 896,362
turn on 21,458 through 972,536
turn on 446,429 through 821,970
toggle 376,423 through 805,455
toggle 494,896 through 715,937
turn on 583,270 through 667,482
turn off 183,468 through 280,548
toggle 623,289 through 750,524
turn on 836,706 through 967,768
turn on 419,569 through 912,908
turn on 428,260 through 660,433
turn off 683,627 through 916,816
turn on 447,973 through 866,980
turn on 688,607 through 938,990
turn on 245,187 through 597,405
turn off 558,843 through 841,942
turn off 325,666 through 713,834
toggle 672,606 through 814,935
turn off 161,812 through 490,954
turn on 950,362 through 985,898
turn on 143,22 through 205,821
turn on 89,762 through 607,790
toggle 234,245 through 827,303
turn on 65,599 through 764,997
turn on 232,466 through 965,695
turn on 739,122 through 975,590
turn off 206,112 through 940,558
toggle 690,365 through 988,552
turn on 907,438 through 977,691
turn off 838,809 through 944,869
turn on 222,12 through 541,832
toggle 337,66 through 669,812
turn on 732,821 through 897,912
toggle 182,862 through 638,996
turn on 955,808 through 983,847
toggle 346,227 through 841,696
turn on 983,270 through 989,756
turn off 874,849 through 876,905
turn off 7,760 through 678,795
toggle 973,977 through 995,983
turn off 911,961 through 914,976
turn on 913,557 through 952,722
turn off 607,933 through 939,999
turn on 226,604 through 517,622
turn off 3,564 through 344,842
toggle 340,578 through 428,610
turn on 248,916 through 687,925
toggle 650,185 through 955,965
toggle 831,359 through 933,536
turn off 544,614 through 896,953
toggle 648,939 through 975,997
turn on 464,269 through 710,521
turn off 643,149 through 791,320
turn off 875,549 through 972,643
turn off 953,969 through 971,972
turn off 236,474 through 772,591
toggle 313,212 through 489,723
toggle 896,829 through 897,837
toggle 544,449 through 995,905
turn off 278,645 through 977,876
turn off 887,947 through 946,977
turn on 342,861 through 725,935
turn on 636,316 through 692,513
toggle 857,470 through 950,528
turn off 736,196 through 826,889
turn on 17,878 through 850,987
turn on 142,968 through 169,987
turn on 46,470 through 912,853
turn on 182,252 through 279,941
toggle 261,143 through 969,657
turn off 69,600 through 518,710
turn on 372,379 through 779,386
toggle 867,391 through 911,601
turn off 174,287 through 900,536
toggle 951,842 through 993,963
turn off 626,733 through 985,827
toggle 622,70 through 666,291
turn off 980,671 through 985,835
turn off 477,63 through 910,72
turn off 779,39 through 940,142
turn on 986,570 through 997,638
toggle 842,805 through 943,985
turn off 890,886 through 976,927
turn off 893,172 through 897,619
turn off 198,780 through 835,826
toggle 202,209 through 219,291
turn off 193,52 through 833,283
toggle 414,427 through 987,972
turn on 375,231 through 668,236
turn off 646,598 through 869,663
toggle 271,462 through 414,650
turn off 679,121 through 845,467
toggle 76,847 through 504,904
turn off 15,617 through 509,810
toggle 248,105 through 312,451
turn off 126,546 through 922,879
turn on 531,831 through 903,872
toggle 602,431 through 892,792
turn off 795,223 through 892,623
toggle 167,721 through 533,929
toggle 813,251 through 998,484
toggle 64,640 through 752,942
turn on 155,955 through 892,985
turn on 251,329 through 996,497
turn off 341,716 through 462,994
toggle 760,127 through 829,189
turn on 86,413 through 408,518
toggle 340,102 through 918,558
turn off 441,642 through 751,889
turn on 785,292 through 845,325
turn off 123,389 through 725,828
turn on 905,73 through 983,270
turn off 807,86 through 879,276
toggle 500,866 through 864,916
turn on 809,366 through 828,534
toggle 219,356 through 720,617
turn off 320,964 through 769,990
turn off 903,167 through 936,631
toggle 300,137 through 333,693
toggle 5,675 through 755,848
turn off 852,235 through 946,783
toggle 355,556 through 941,664
turn on 810,830 through 867,891
turn off 509,869 through 667,903
toggle 769,400 through 873,892
turn on 553,614 through 810,729
turn on 179,873 through 589,962
turn off 466,866 through 768,926
toggle 143,943 through 465,984
toggle 182,380 through 569,552
turn off 735,808 through 917,910
turn on 731,802 through 910,847
turn off 522,74 through 731,485
turn on 444,127 through 566,996
turn off 232,962 through 893,979
turn off 231,492 through 790,976
turn on 874,567 through 943,684
toggle 911,840 through 990,932
toggle 547,895 through 667,935
turn off 93,294 through 648,636
turn off 190,902 through 532,970
turn off 451,530 through 704,613
toggle 936,774 through 937,775
turn off 116,843 through 533,934
turn on 950,906 through 986,993
turn on 910,51 through 945,989
turn on 986,498 through 994,945
turn off 125,324 through 433,704
turn off 60,313 through 75,728
turn on 899,494 through 940,947
toggle 832,316 through 971,817
toggle 994,983 through 998,984
toggle 23,353 through 917,845
toggle 174,799 through 658,859
turn off 490,878 through 534,887
turn off 623,963 through 917,975
toggle 721,333 through 816,975
toggle 589,687 through 890,921
turn on 936,388 through 948,560
turn off 485,17 through 655,610
turn on 435,158 through 689,495
turn on 192,934 through 734,936
turn off 299,723 through 622,847
toggle 484,160 through 812,942
turn off 245,754 through 818,851
turn on 298,419 through 824,634
toggle 868,687 through 969,760
toggle 131,250 through 685,426
turn off 201,954 through 997,983
turn on 353,910 through 832,961
turn off 518,781 through 645,875
turn off 866,97 through 924,784
toggle 836,599 through 857,767
turn on 80,957 through 776,968
toggle 277,130 through 513,244
turn off 62,266 through 854,434
turn on 792,764 through 872,842
turn off 160,949 through 273,989
turn off 664,203 through 694,754
toggle 491,615 through 998,836
turn off 210,146 through 221,482
turn off 209,780 through 572,894
turn on 766,112 through 792,868
turn on 222,12 through 856,241'''

# %%
import numpy as np

grid = np.ones((1000,1000), dtype=bool)

# %%
def turn_on(grid, ul, lr):
  grid[ul[0]:lr[0]+1, ul[1]:lr[1]+1] = True
  return grid

y = np.asarray([[False,True],[True,False]])
print(y)
y = turn_on(y, (0,0), (0,0))
y
# Out:
# [[False  True]
#  [ True False]]
# array([[ True,  True],
#        [ True, False]])

# %%
def toggle(grid, ul, lr):
  grid[ul[0]:lr[0]+1, ul[1]:lr[1]+1] = (grid[ul[0]:lr[0]+1, ul[1]:lr[1]+1] != True)
  return grid

def toggle2(grid, ul, lr):
  grid[ul[0]:lr[0]+1, ul[1]:lr[1]+1] ^= True
  return grid

print(toggle2(np.eye(3, dtype=bool), (1,1), (2,2)))

print(np.asarray([True,False], dtype=bool) != True)
y = np.asarray([[True,False],[True,False]])
print(y)
y = toggle(y, (0,0), (0,0))
y
# Out:
# [[ True False False]
#  [False False  True]
#  [False  True False]]
# [False  True]
# [[ True False]
#  [ True False]]
# array([[False, False],
#        [ True, False]])

# %%
np.array([True, False]) ^ True
# Out:
# array([False,  True])

# %%
a = np.array([True, False, True])
a[1:] ^= True
a
# Out:
# array([ True,  True, False])

# %%
def turn_off(grid, ul, lr):
  grid[ul[0]:lr[0]+1, ul[1]:lr[1]+1] = False
  return grid

y = np.asarray([[False,True],[True,False]])
print(y)
y = turn_off(y, (0,0), (1,1))
y
# Out:
# [[False  True]
#  [ True False]]
# array([[False, False],
#        [False, False]])

# %%
import matplotlib.pyplot as plt

plt.pcolor(-1*np.asarray([[False,True],[True,False]]))

# %%
plt.pcolor(-1*y)

# %%
import ast

def interpret(num):
  x, y = ast.literal_eval(num)
  return x,y

interpret('631,78')[0]
# Out:
# 631

# %%
def apply_line(grid, line):
  line_list = line.split(' ')
  if line_list[0]=='toggle':
    func = toggle
    ul = interpret(line_list[1])
    lr = interpret(line_list[3])
  elif line_list[0]=='turn':
    ul = interpret(line_list[2])
    lr = interpret(line_list[4])
    if line_list[1]=='on':
      func = turn_on
    elif line_list[1]=='off':
      func = turn_off
    else:
      raise Error("Error parsing turn line, line is", line)
  else:
    raise Error("Error parsing line, line is", line)

  return func(grid, ul, lr)

# %%
grid = np.zeros((1000,1000), dtype=bool) #zero is false

for line_num, line in enumerate(input.split('\n')):
  if line_num%50 == 0:
    plt.pcolor(grid)
    plt.show()
  grid = apply_line(grid, line)
  print('now applying instruction:', line)

plt.pcolor(grid)
plt.show()

grid.sum()
# Out:
# now applying instruction: toggle 461,550 through 564,900
# now applying instruction: turn off 370,39 through 425,839
# now applying instruction: turn off 464,858 through 833,915
# now applying instruction: turn off 812,389 through 865,874
# now applying instruction: turn on 599,989 through 806,993
# now applying instruction: turn on 376,415 through 768,548
# now applying instruction: turn on 606,361 through 892,600
# now applying instruction: turn off 448,208 through 645,684
# now applying instruction: toggle 50,472 through 452,788
# now applying instruction: toggle 205,417 through 703,826
# now applying instruction: toggle 533,331 through 906,873
# now applying instruction: toggle 857,493 through 989,970
# now applying instruction: turn off 631,950 through 894,975
# now applying instruction: turn off 387,19 through 720,700
# now applying instruction: turn off 511,843 through 581,945
# now applying instruction: toggle 514,557 through 662,883
# now applying instruction: turn off 269,809 through 876,847
# now applying instruction: turn off 149,517 through 716,777
# now applying instruction: turn off 994,939 through 998,988
# now applying instruction: toggle 467,662 through 555,957
# now applying instruction: turn on 952,417 through 954,845
# now applying instruction: turn on 565,226 through 944,880
# now applying instruction: turn on 214,319 through 805,722
# now applying instruction: toggle 532,276 through 636,847
# now applying instruction: toggle 619,80 through 689,507
# now applying instruction: turn on 390,706 through 884,722
# now applying instruction: toggle 17,634 through 537,766
# now applying instruction: toggle 706,440 through 834,441
# now applying instruction: toggle 318,207 through 499,530
# now applying instruction: toggle 698,185 through 830,343
# now applying instruction: toggle 566,679 through 744,716
# now applying instruction: toggle 347,482 through 959,482
# now applying instruction: toggle 39,799 through 981,872
# now applying instruction: turn on 583,543 through 846,710
# now applying instruction: turn off 367,664 through 595,872
# now applying instruction: turn on 805,439 through 964,995
# now applying instruction: toggle 209,584 through 513,802
# now applying instruction: turn off 106,497 through 266,770
# now applying instruction: turn on 975,2 through 984,623
# now applying instruction: turn off 316,684 through 369,876
# now applying instruction: turn off 30,309 through 259,554
# now applying instruction: turn off 399,680 through 861,942
# now applying instruction: toggle 227,740 through 850,829
# now applying instruction: turn on 386,603 through 552,879
# now applying instruction: turn off 703,795 through 791,963
# now applying instruction: turn off 573,803 through 996,878
# now applying instruction: turn off 993,939 through 997,951
# now applying instruction: turn on 809,221 through 869,723
# now applying instruction: turn off 38,720 through 682,751
# now applying instruction: turn off 318,732 through 720,976
# now applying instruction: toggle 88,459 through 392,654
# now applying instruction: turn off 865,654 through 911,956
# now applying instruction: toggle 264,284 through 857,956
# now applying instruction: turn off 281,776 through 610,797
# now applying instruction: toggle 492,660 through 647,910
# now applying instruction: turn off 879,703 through 925,981
# now applying instruction: turn off 772,414 through 974,518
# now applying instruction: turn on 694,41 through 755,96
# now applying instruction: turn on 452,406 through 885,881
# now applying instruction: turn off 107,905 through 497,910
# now applying instruction: turn off 647,222 through 910,532
# now applying instruction: turn on 679,40 through 845,358
# now applying instruction: turn off 144,205 through 556,362
# now applying instruction: turn on 871,804 through 962,878
# now applying instruction: turn on 545,676 through 545,929
# now applying instruction: turn off 316,716 through 413,941
# now applying instruction: toggle 488,826 through 755,971
# now applying instruction: toggle 957,832 through 976,992
# now applying instruction: toggle 857,770 through 905,964
# now applying instruction: toggle 319,198 through 787,673
# now applying instruction: turn on 832,813 through 863,844
# now applying instruction: turn on 818,296 through 818,681
# now applying instruction: turn on 71,699 through 91,960
# now applying instruction: turn off 838,578 through 967,928
# now applying instruction: toggle 440,856 through 507,942
# now applying instruction: toggle 121,970 through 151,974
# now applying instruction: toggle 391,192 through 659,751
# now applying instruction: turn on 78,210 through 681,419
# now applying instruction: turn on 324,591 through 593,939
# now applying instruction: toggle 159,366 through 249,760
# now applying instruction: turn off 617,167 through 954,601
# now applying instruction: toggle 484,607 through 733,657
# now applying instruction: turn on 587,96 through 888,819
# now applying instruction: turn off 680,984 through 941,991
# now applying instruction: turn on 800,512 through 968,691
# now applying instruction: turn off 123,588 through 853,603
# now applying instruction: turn on 1,862 through 507,912
# now applying instruction: turn on 699,839 through 973,878
# now applying instruction: turn off 848,89 through 887,893
# now applying instruction: toggle 344,353 through 462,403
# now applying instruction: turn on 780,731 through 841,760
# now applying instruction: toggle 693,973 through 847,984
# now applying instruction: toggle 989,936 through 996,958
# now applying instruction: toggle 168,475 through 206,963
# now applying instruction: turn on 742,683 through 769,845
# now applying instruction: toggle 768,116 through 987,396
# now applying instruction: turn on 190,364 through 617,526
# now applying instruction: turn off 470,266 through 530,839
# now applying instruction: toggle 122,497 through 969,645
# now applying instruction: turn off 492,432 through 827,790
# now applying instruction: turn on 505,636 through 957,820
# now applying instruction: turn on 295,476 through 698,958
# now applying instruction: toggle 63,298 through 202,396
# now applying instruction: turn on 157,315 through 412,939
# now applying instruction: turn off 69,789 through 134,837
# now applying instruction: turn off 678,335 through 896,541
# now applying instruction: toggle 140,516 through 842,668
# now applying instruction: turn off 697,585 through 712,668
# now applying instruction: toggle 507,832 through 578,949
# now applying instruction: turn on 678,279 through 886,621
# now applying instruction: toggle 449,744 through 826,910
# now applying instruction: turn off 835,354 through 921,741
# now applying instruction: toggle 924,878 through 985,952
# now applying instruction: turn on 666,503 through 922,905
# now applying instruction: turn on 947,453 through 961,587
# now applying instruction: toggle 525,190 through 795,654
# now applying instruction: turn off 62,320 through 896,362
# now applying instruction: turn on 21,458 through 972,536
# now applying instruction: turn on 446,429 through 821,970
# now applying instruction: toggle 376,423 through 805,455
# now applying instruction: toggle 494,896 through 715,937
# now applying instruction: turn on 583,270 through 667,482
# now applying instruction: turn off 183,468 through 280,548
# now applying instruction: toggle 623,289 through 750,524
# now applying instruction: turn on 836,706 through 967,768
# now applying instruction: turn on 419,569 through 912,908
# now applying instruction: turn on 428,260 through 660,433
# now applying instruction: turn off 683,627 through 916,816
# now applying instruction: turn on 447,973 through 866,980
# now applying instruction: turn on 688,607 through 938,990
# now applying instruction: turn on 245,187 through 597,405
# now applying instruction: turn off 558,843 through 841,942
# now applying instruction: turn off 325,666 through 713,834
# now applying instruction: toggle 672,606 through 814,935
# now applying instruction: turn off 161,812 through 490,954
# now applying instruction: turn on 950,362 through 985,898
# now applying instruction: turn on 143,22 through 205,821
# now applying instruction: turn on 89,762 through 607,790
# now applying instruction: toggle 234,245 through 827,303
# now applying instruction: turn on 65,599 through 764,997
# now applying instruction: turn on 232,466 through 965,695
# now applying instruction: turn on 739,122 through 975,590
# now applying instruction: turn off 206,112 through 940,558
# now applying instruction: toggle 690,365 through 988,552
# now applying instruction: turn on 907,438 through 977,691
# now applying instruction: turn off 838,809 through 944,869
# now applying instruction: turn on 222,12 through 541,832
# now applying instruction: toggle 337,66 through 669,812
# now applying instruction: turn on 732,821 through 897,912
# now applying instruction: toggle 182,862 through 638,996
# now applying instruction: turn on 955,808 through 983,847
# now applying instruction: toggle 346,227 through 841,696
# now applying instruction: turn on 983,270 through 989,756
# now applying instruction: turn off 874,849 through 876,905
# now applying instruction: turn off 7,760 through 678,795
# now applying instruction: toggle 973,977 through 995,983
# now applying instruction: turn off 911,961 through 914,976
# now applying instruction: turn on 913,557 through 952,722
# now applying instruction: turn off 607,933 through 939,999
# now applying instruction: turn on 226,604 through 517,622
# now applying instruction: turn off 3,564 through 344,842
# now applying instruction: toggle 340,578 through 428,610
# now applying instruction: turn on 248,916 through 687,925
# now applying instruction: toggle 650,185 through 955,965
# now applying instruction: toggle 831,359 through 933,536
# now applying instruction: turn off 544,614 through 896,953
# now applying instruction: toggle 648,939 through 975,997
# now applying instruction: turn on 464,269 through 710,521
# now applying instruction: turn off 643,149 through 791,320
# now applying instruction: turn off 875,549 through 972,643
# now applying instruction: turn off 953,969 through 971,972
# now applying instruction: turn off 236,474 through 772,591
# now applying instruction: toggle 313,212 through 489,723
# now applying instruction: toggle 896,829 through 897,837
# now applying instruction: toggle 544,449 through 995,905
# now applying instruction: turn off 278,645 through 977,876
# now applying instruction: turn off 887,947 through 946,977
# now applying instruction: turn on 342,861 through 725,935
# now applying instruction: turn on 636,316 through 692,513
# now applying instruction: toggle 857,470 through 950,528
# now applying instruction: turn off 736,196 through 826,889
# now applying instruction: turn on 17,878 through 850,987
# now applying instruction: turn on 142,968 through 169,987
# now applying instruction: turn on 46,470 through 912,853
# now applying instruction: turn on 182,252 through 279,941
# now applying instruction: toggle 261,143 through 969,657
# now applying instruction: turn off 69,600 through 518,710
# now applying instruction: turn on 372,379 through 779,386
# now applying instruction: toggle 867,391 through 911,601
# now applying instruction: turn off 174,287 through 900,536
# now applying instruction: toggle 951,842 through 993,963
# now applying instruction: turn off 626,733 through 985,827
# now applying instruction: toggle 622,70 through 666,291
# now applying instruction: turn off 980,671 through 985,835
# now applying instruction: turn off 477,63 through 910,72
# now applying instruction: turn off 779,39 through 940,142
# now applying instruction: turn on 986,570 through 997,638
# now applying instruction: toggle 842,805 through 943,985
# now applying instruction: turn off 890,886 through 976,927
# now applying instruction: turn off 893,172 through 897,619
# now applying instruction: turn off 198,780 through 835,826
# now applying instruction: toggle 202,209 through 219,291
# now applying instruction: turn off 193,52 through 833,283
# now applying instruction: toggle 414,427 through 987,972
# now applying instruction: turn on 375,231 through 668,236
# now applying instruction: turn off 646,598 through 869,663
# now applying instruction: toggle 271,462 through 414,650
# now applying instruction: turn off 679,121 through 845,467
# now applying instruction: toggle 76,847 through 504,904
# now applying instruction: turn off 15,617 through 509,810
# now applying instruction: toggle 248,105 through 312,451
# now applying instruction: turn off 126,546 through 922,879
# now applying instruction: turn on 531,831 through 903,872
# now applying instruction: toggle 602,431 through 892,792
# now applying instruction: turn off 795,223 through 892,623
# now applying instruction: toggle 167,721 through 533,929
# now applying instruction: toggle 813,251 through 998,484
# now applying instruction: toggle 64,640 through 752,942
# now applying instruction: turn on 155,955 through 892,985
# now applying instruction: turn on 251,329 through 996,497
# now applying instruction: turn off 341,716 through 462,994
# now applying instruction: toggle 760,127 through 829,189
# now applying instruction: turn on 86,413 through 408,518
# now applying instruction: toggle 340,102 through 918,558
# now applying instruction: turn off 441,642 through 751,889
# now applying instruction: turn on 785,292 through 845,325
# now applying instruction: turn off 123,389 through 725,828
# now applying instruction: turn on 905,73 through 983,270
# now applying instruction: turn off 807,86 through 879,276
# now applying instruction: toggle 500,866 through 864,916
# now applying instruction: turn on 809,366 through 828,534
# now applying instruction: toggle 219,356 through 720,617
# now applying instruction: turn off 320,964 through 769,990
# now applying instruction: turn off 903,167 through 936,631
# now applying instruction: toggle 300,137 through 333,693
# now applying instruction: toggle 5,675 through 755,848
# now applying instruction: turn off 852,235 through 946,783
# now applying instruction: toggle 355,556 through 941,664
# now applying instruction: turn on 810,830 through 867,891
# now applying instruction: turn off 509,869 through 667,903
# now applying instruction: toggle 769,400 through 873,892
# now applying instruction: turn on 553,614 through 810,729
# now applying instruction: turn on 179,873 through 589,962
# now applying instruction: turn off 466,866 through 768,926
# now applying instruction: toggle 143,943 through 465,984
# now applying instruction: toggle 182,380 through 569,552
# now applying instruction: turn off 735,808 through 917,910
# now applying instruction: turn on 731,802 through 910,847
# now applying instruction: turn off 522,74 through 731,485
# now applying instruction: turn on 444,127 through 566,996
# now applying instruction: turn off 232,962 through 893,979
# now applying instruction: turn off 231,492 through 790,976
# now applying instruction: turn on 874,567 through 943,684
# now applying instruction: toggle 911,840 through 990,932
# now applying instruction: toggle 547,895 through 667,935
# now applying instruction: turn off 93,294 through 648,636
# now applying instruction: turn off 190,902 through 532,970
# now applying instruction: turn off 451,530 through 704,613
# now applying instruction: toggle 936,774 through 937,775
# now applying instruction: turn off 116,843 through 533,934
# now applying instruction: turn on 950,906 through 986,993
# now applying instruction: turn on 910,51 through 945,989
# now applying instruction: turn on 986,498 through 994,945
# now applying instruction: turn off 125,324 through 433,704
# now applying instruction: turn off 60,313 through 75,728
# now applying instruction: turn on 899,494 through 940,947
# now applying instruction: toggle 832,316 through 971,817
# now applying instruction: toggle 994,983 through 998,984
# now applying instruction: toggle 23,353 through 917,845
# now applying instruction: toggle 174,799 through 658,859
# now applying instruction: turn off 490,878 through 534,887
# now applying instruction: turn off 623,963 through 917,975
# now applying instruction: toggle 721,333 through 816,975
# now applying instruction: toggle 589,687 through 890,921
# now applying instruction: turn on 936,388 through 948,560
# now applying instruction: turn off 485,17 through 655,610
# now applying instruction: turn on 435,158 through 689,495
# now applying instruction: turn on 192,934 through 734,936
# now applying instruction: turn off 299,723 through 622,847
# now applying instruction: toggle 484,160 through 812,942
# now applying instruction: turn off 245,754 through 818,851
# now applying instruction: turn on 298,419 through 824,634
# now applying instruction: toggle 868,687 through 969,760
# now applying instruction: toggle 131,250 through 685,426
# now applying instruction: turn off 201,954 through 997,983
# now applying instruction: turn on 353,910 through 832,961
# now applying instruction: turn off 518,781 through 645,875
# now applying instruction: turn off 866,97 through 924,784
# now applying instruction: toggle 836,599 through 857,767
# now applying instruction: turn on 80,957 through 776,968
# now applying instruction: toggle 277,130 through 513,244
# now applying instruction: turn off 62,266 through 854,434
# now applying instruction: turn on 792,764 through 872,842
# now applying instruction: turn off 160,949 through 273,989
# now applying instruction: turn off 664,203 through 694,754
# now applying instruction: toggle 491,615 through 998,836
# now applying instruction: turn off 210,146 through 221,482
# now applying instruction: turn off 209,780 through 572,894
# now applying instruction: turn on 766,112 through 792,868
# now applying instruction: turn on 222,12 through 856,241
# 543903

# %% [markdown]
# https://adventofcode.com/2015/day/6#part2

# %%
len(input.split('\n'))
# Out:
# 300

# %%
np.iinfo(np.int16).max # maximum that can be represented by np.int16
# Out:
# 32767

# %%
def blank_grid2():
  return np.zeros((1000, 1000), dtype=np.int16)

# %%
def clip_below0(grid):
  return np.maximum(grid, 0)

# %%
def turn_on2(grid, ul, lr):
  grid[ul[0]:lr[0]+1, ul[1]:lr[1]+1] += 1

test_grid = np.eye(3, dtype=np.int64)
turn_on2(test_grid, (1,1), (2,2))
test_grid
# Out:
# array([[1, 0, 0],
#        [0, 2, 1],
#        [0, 1, 2]])

# %%
def turn_off2(grid, ul, lr):
  view = grid[ul[0]:lr[0]+1, ul[1]:lr[1]+1]
  view -= 1
  view[:] = clip_below0(view)

test_grid = np.eye(3, dtype=np.int64)
test_grid[1,2] = 5
turn_off2(test_grid, (1,1), (2,2))
test_grid
# Out:
# array([[1, 0, 0],
#        [0, 0, 4],
#        [0, 0, 0]])

# %%
def toggle2(grid, ul, lr):
  grid[ul[0]:lr[0]+1, ul[1]:lr[1]+1] += 2

test_grid = np.eye(3, dtype=np.int64)
toggle2(test_grid, (1,1), (2,2))
test_grid
# Out:
# array([[1, 0, 0],
#        [0, 3, 2],
#        [0, 2, 3]])

# %%
def apply_line2(grid, line):
  line_list = line.split(' ')
  if line_list[0]=='toggle':
    func = toggle2
    ul = interpret(line_list[1])
    lr = interpret(line_list[3])
  elif line_list[0]=='turn':
    ul = interpret(line_list[2])
    lr = interpret(line_list[4])
    if line_list[1]=='on':
      func = turn_on2
    elif line_list[1]=='off':
      func = turn_off2
    else:
      raise Error("Error parsing turn line, line is", line)
  else:
    raise Error("Error parsing line, line is", line)

  func(grid, ul, lr)

# %%
grid = blank_grid2()

for line_num, line in enumerate(input.split('\n')):
  if line_num%50 == 0:
    plt.pcolor(grid)
    plt.show()
  apply_line2(grid, line)
  print('now applying instruction:', line)

plt.pcolor(grid)
plt.show()

grid.sum()
# Out:
# now applying instruction: toggle 461,550 through 564,900
# now applying instruction: turn off 370,39 through 425,839
# now applying instruction: turn off 464,858 through 833,915
# now applying instruction: turn off 812,389 through 865,874
# now applying instruction: turn on 599,989 through 806,993
# now applying instruction: turn on 376,415 through 768,548
# now applying instruction: turn on 606,361 through 892,600
# now applying instruction: turn off 448,208 through 645,684
# now applying instruction: toggle 50,472 through 452,788
# now applying instruction: toggle 205,417 through 703,826
# now applying instruction: toggle 533,331 through 906,873
# now applying instruction: toggle 857,493 through 989,970
# now applying instruction: turn off 631,950 through 894,975
# now applying instruction: turn off 387,19 through 720,700
# now applying instruction: turn off 511,843 through 581,945
# now applying instruction: toggle 514,557 through 662,883
# now applying instruction: turn off 269,809 through 876,847
# now applying instruction: turn off 149,517 through 716,777
# now applying instruction: turn off 994,939 through 998,988
# now applying instruction: toggle 467,662 through 555,957
# now applying instruction: turn on 952,417 through 954,845
# now applying instruction: turn on 565,226 through 944,880
# now applying instruction: turn on 214,319 through 805,722
# now applying instruction: toggle 532,276 through 636,847
# now applying instruction: toggle 619,80 through 689,507
# now applying instruction: turn on 390,706 through 884,722
# now applying instruction: toggle 17,634 through 537,766
# now applying instruction: toggle 706,440 through 834,441
# now applying instruction: toggle 318,207 through 499,530
# now applying instruction: toggle 698,185 through 830,343
# now applying instruction: toggle 566,679 through 744,716
# now applying instruction: toggle 347,482 through 959,482
# now applying instruction: toggle 39,799 through 981,872
# now applying instruction: turn on 583,543 through 846,710
# now applying instruction: turn off 367,664 through 595,872
# now applying instruction: turn on 805,439 through 964,995
# now applying instruction: toggle 209,584 through 513,802
# now applying instruction: turn off 106,497 through 266,770
# now applying instruction: turn on 975,2 through 984,623
# now applying instruction: turn off 316,684 through 369,876
# now applying instruction: turn off 30,309 through 259,554
# now applying instruction: turn off 399,680 through 861,942
# now applying instruction: toggle 227,740 through 850,829
# now applying instruction: turn on 386,603 through 552,879
# now applying instruction: turn off 703,795 through 791,963
# now applying instruction: turn off 573,803 through 996,878
# now applying instruction: turn off 993,939 through 997,951
# now applying instruction: turn on 809,221 through 869,723
# now applying instruction: turn off 38,720 through 682,751
# now applying instruction: turn off 318,732 through 720,976
# now applying instruction: toggle 88,459 through 392,654
# now applying instruction: turn off 865,654 through 911,956
# now applying instruction: toggle 264,284 through 857,956
# now applying instruction: turn off 281,776 through 610,797
# now applying instruction: toggle 492,660 through 647,910
# now applying instruction: turn off 879,703 through 925,981
# now applying instruction: turn off 772,414 through 974,518
# now applying instruction: turn on 694,41 through 755,96
# now applying instruction: turn on 452,406 through 885,881
# now applying instruction: turn off 107,905 through 497,910
# now applying instruction: turn off 647,222 through 910,532
# now applying instruction: turn on 679,40 through 845,358
# now applying instruction: turn off 144,205 through 556,362
# now applying instruction: turn on 871,804 through 962,878
# now applying instruction: turn on 545,676 through 545,929
# now applying instruction: turn off 316,716 through 413,941
# now applying instruction: toggle 488,826 through 755,971
# now applying instruction: toggle 957,832 through 976,992
# now applying instruction: toggle 857,770 through 905,964
# now applying instruction: toggle 319,198 through 787,673
# now applying instruction: turn on 832,813 through 863,844
# now applying instruction: turn on 818,296 through 818,681
# now applying instruction: turn on 71,699 through 91,960
# now applying instruction: turn off 838,578 through 967,928
# now applying instruction: toggle 440,856 through 507,942
# now applying instruction: toggle 121,970 through 151,974
# now applying instruction: toggle 391,192 through 659,751
# now applying instruction: turn on 78,210 through 681,419
# now applying instruction: turn on 324,591 through 593,939
# now applying instruction: toggle 159,366 through 249,760
# now applying instruction: turn off 617,167 through 954,601
# now applying instruction: toggle 484,607 through 733,657
# now applying instruction: turn on 587,96 through 888,819
# now applying instruction: turn off 680,984 through 941,991
# now applying instruction: turn on 800,512 through 968,691
# now applying instruction: turn off 123,588 through 853,603
# now applying instruction: turn on 1,862 through 507,912
# now applying instruction: turn on 699,839 through 973,878
# now applying instruction: turn off 848,89 through 887,893
# now applying instruction: toggle 344,353 through 462,403
# now applying instruction: turn on 780,731 through 841,760
# now applying instruction: toggle 693,973 through 847,984
# now applying instruction: toggle 989,936 through 996,958
# now applying instruction: toggle 168,475 through 206,963
# now applying instruction: turn on 742,683 through 769,845
# now applying instruction: toggle 768,116 through 987,396
# now applying instruction: turn on 190,364 through 617,526
# now applying instruction: turn off 470,266 through 530,839
# now applying instruction: toggle 122,497 through 969,645
# now applying instruction: turn off 492,432 through 827,790
# now applying instruction: turn on 505,636 through 957,820
# now applying instruction: turn on 295,476 through 698,958
# now applying instruction: toggle 63,298 through 202,396
# now applying instruction: turn on 157,315 through 412,939
# now applying instruction: turn off 69,789 through 134,837
# now applying instruction: turn off 678,335 through 896,541
# now applying instruction: toggle 140,516 through 842,668
# now applying instruction: turn off 697,585 through 712,668
# now applying instruction: toggle 507,832 through 578,949
# now applying instruction: turn on 678,279 through 886,621
# now applying instruction: toggle 449,744 through 826,910
# now applying instruction: turn off 835,354 through 921,741
# now applying instruction: toggle 924,878 through 985,952
# now applying instruction: turn on 666,503 through 922,905
# now applying instruction: turn on 947,453 through 961,587
# now applying instruction: toggle 525,190 through 795,654
# now applying instruction: turn off 62,320 through 896,362
# now applying instruction: turn on 21,458 through 972,536
# now applying instruction: turn on 446,429 through 821,970
# now applying instruction: toggle 376,423 through 805,455
# now applying instruction: toggle 494,896 through 715,937
# now applying instruction: turn on 583,270 through 667,482
# now applying instruction: turn off 183,468 through 280,548
# now applying instruction: toggle 623,289 through 750,524
# now applying instruction: turn on 836,706 through 967,768
# now applying instruction: turn on 419,569 through 912,908
# now applying instruction: turn on 428,260 through 660,433
# now applying instruction: turn off 683,627 through 916,816
# now applying instruction: turn on 447,973 through 866,980
# now applying instruction: turn on 688,607 through 938,990
# now applying instruction: turn on 245,187 through 597,405
# now applying instruction: turn off 558,843 through 841,942
# now applying instruction: turn off 325,666 through 713,834
# now applying instruction: toggle 672,606 through 814,935
# now applying instruction: turn off 161,812 through 490,954
# now applying instruction: turn on 950,362 through 985,898
# now applying instruction: turn on 143,22 through 205,821
# now applying instruction: turn on 89,762 through 607,790
# now applying instruction: toggle 234,245 through 827,303
# now applying instruction: turn on 65,599 through 764,997
# now applying instruction: turn on 232,466 through 965,695
# now applying instruction: turn on 739,122 through 975,590
# now applying instruction: turn off 206,112 through 940,558
# now applying instruction: toggle 690,365 through 988,552
# now applying instruction: turn on 907,438 through 977,691
# now applying instruction: turn off 838,809 through 944,869
# now applying instruction: turn on 222,12 through 541,832
# now applying instruction: toggle 337,66 through 669,812
# now applying instruction: turn on 732,821 through 897,912
# now applying instruction: toggle 182,862 through 638,996
# now applying instruction: turn on 955,808 through 983,847
# now applying instruction: toggle 346,227 through 841,696
# now applying instruction: turn on 983,270 through 989,756
# now applying instruction: turn off 874,849 through 876,905
# now applying instruction: turn off 7,760 through 678,795
# now applying instruction: toggle 973,977 through 995,983
# now applying instruction: turn off 911,961 through 914,976
# now applying instruction: turn on 913,557 through 952,722
# now applying instruction: turn off 607,933 through 939,999
# now applying instruction: turn on 226,604 through 517,622
# now applying instruction: turn off 3,564 through 344,842
# now applying instruction: toggle 340,578 through 428,610
# now applying instruction: turn on 248,916 through 687,925
# now applying instruction: toggle 650,185 through 955,965
# now applying instruction: toggle 831,359 through 933,536
# now applying instruction: turn off 544,614 through 896,953
# now applying instruction: toggle 648,939 through 975,997
# now applying instruction: turn on 464,269 through 710,521
# now applying instruction: turn off 643,149 through 791,320
# now applying instruction: turn off 875,549 through 972,643
# now applying instruction: turn off 953,969 through 971,972
# now applying instruction: turn off 236,474 through 772,591
# now applying instruction: toggle 313,212 through 489,723
# now applying instruction: toggle 896,829 through 897,837
# now applying instruction: toggle 544,449 through 995,905
# now applying instruction: turn off 278,645 through 977,876
# now applying instruction: turn off 887,947 through 946,977
# now applying instruction: turn on 342,861 through 725,935
# now applying instruction: turn on 636,316 through 692,513
# now applying instruction: toggle 857,470 through 950,528
# now applying instruction: turn off 736,196 through 826,889
# now applying instruction: turn on 17,878 through 850,987
# now applying instruction: turn on 142,968 through 169,987
# now applying instruction: turn on 46,470 through 912,853
# now applying instruction: turn on 182,252 through 279,941
# now applying instruction: toggle 261,143 through 969,657
# now applying instruction: turn off 69,600 through 518,710
# now applying instruction: turn on 372,379 through 779,386
# now applying instruction: toggle 867,391 through 911,601
# now applying instruction: turn off 174,287 through 900,536
# now applying instruction: toggle 951,842 through 993,963
# now applying instruction: turn off 626,733 through 985,827
# now applying instruction: toggle 622,70 through 666,291
# now applying instruction: turn off 980,671 through 985,835
# now applying instruction: turn off 477,63 through 910,72
# now applying instruction: turn off 779,39 through 940,142
# now applying instruction: turn on 986,570 through 997,638
# now applying instruction: toggle 842,805 through 943,985
# now applying instruction: turn off 890,886 through 976,927
# now applying instruction: turn off 893,172 through 897,619
# now applying instruction: turn off 198,780 through 835,826
# now applying instruction: toggle 202,209 through 219,291
# now applying instruction: turn off 193,52 through 833,283
# now applying instruction: toggle 414,427 through 987,972
# now applying instruction: turn on 375,231 through 668,236
# now applying instruction: turn off 646,598 through 869,663
# now applying instruction: toggle 271,462 through 414,650
# now applying instruction: turn off 679,121 through 845,467
# now applying instruction: toggle 76,847 through 504,904
# now applying instruction: turn off 15,617 through 509,810
# now applying instruction: toggle 248,105 through 312,451
# now applying instruction: turn off 126,546 through 922,879
# now applying instruction: turn on 531,831 through 903,872
# now applying instruction: toggle 602,431 through 892,792
# now applying instruction: turn off 795,223 through 892,623
# now applying instruction: toggle 167,721 through 533,929
# now applying instruction: toggle 813,251 through 998,484
# now applying instruction: toggle 64,640 through 752,942
# now applying instruction: turn on 155,955 through 892,985
# now applying instruction: turn on 251,329 through 996,497
# now applying instruction: turn off 341,716 through 462,994
# now applying instruction: toggle 760,127 through 829,189
# now applying instruction: turn on 86,413 through 408,518
# now applying instruction: toggle 340,102 through 918,558
# now applying instruction: turn off 441,642 through 751,889
# now applying instruction: turn on 785,292 through 845,325
# now applying instruction: turn off 123,389 through 725,828
# now applying instruction: turn on 905,73 through 983,270
# now applying instruction: turn off 807,86 through 879,276
# now applying instruction: toggle 500,866 through 864,916
# now applying instruction: turn on 809,366 through 828,534
# now applying instruction: toggle 219,356 through 720,617
# now applying instruction: turn off 320,964 through 769,990
# now applying instruction: turn off 903,167 through 936,631
# now applying instruction: toggle 300,137 through 333,693
# now applying instruction: toggle 5,675 through 755,848
# now applying instruction: turn off 852,235 through 946,783
# now applying instruction: toggle 355,556 through 941,664
# now applying instruction: turn on 810,830 through 867,891
# now applying instruction: turn off 509,869 through 667,903
# now applying instruction: toggle 769,400 through 873,892
# now applying instruction: turn on 553,614 through 810,729
# now applying instruction: turn on 179,873 through 589,962
# now applying instruction: turn off 466,866 through 768,926
# now applying instruction: toggle 143,943 through 465,984
# now applying instruction: toggle 182,380 through 569,552
# now applying instruction: turn off 735,808 through 917,910
# now applying instruction: turn on 731,802 through 910,847
# now applying instruction: turn off 522,74 through 731,485
# now applying instruction: turn on 444,127 through 566,996
# now applying instruction: turn off 232,962 through 893,979
# now applying instruction: turn off 231,492 through 790,976
# now applying instruction: turn on 874,567 through 943,684
# now applying instruction: toggle 911,840 through 990,932
# now applying instruction: toggle 547,895 through 667,935
# now applying instruction: turn off 93,294 through 648,636
# now applying instruction: turn off 190,902 through 532,970
# now applying instruction: turn off 451,530 through 704,613
# now applying instruction: toggle 936,774 through 937,775
# now applying instruction: turn off 116,843 through 533,934
# now applying instruction: turn on 950,906 through 986,993
# now applying instruction: turn on 910,51 through 945,989
# now applying instruction: turn on 986,498 through 994,945
# now applying instruction: turn off 125,324 through 433,704
# now applying instruction: turn off 60,313 through 75,728
# now applying instruction: turn on 899,494 through 940,947
# now applying instruction: toggle 832,316 through 971,817
# now applying instruction: toggle 994,983 through 998,984
# now applying instruction: toggle 23,353 through 917,845
# now applying instruction: toggle 174,799 through 658,859
# now applying instruction: turn off 490,878 through 534,887
# now applying instruction: turn off 623,963 through 917,975
# now applying instruction: toggle 721,333 through 816,975
# now applying instruction: toggle 589,687 through 890,921
# now applying instruction: turn on 936,388 through 948,560
# now applying instruction: turn off 485,17 through 655,610
# now applying instruction: turn on 435,158 through 689,495
# now applying instruction: turn on 192,934 through 734,936
# now applying instruction: turn off 299,723 through 622,847
# now applying instruction: toggle 484,160 through 812,942
# now applying instruction: turn off 245,754 through 818,851
# now applying instruction: turn on 298,419 through 824,634
# now applying instruction: toggle 868,687 through 969,760
# now applying instruction: toggle 131,250 through 685,426
# now applying instruction: turn off 201,954 through 997,983
# now applying instruction: turn on 353,910 through 832,961
# now applying instruction: turn off 518,781 through 645,875
# now applying instruction: turn off 866,97 through 924,784
# now applying instruction: toggle 836,599 through 857,767
# now applying instruction: turn on 80,957 through 776,968
# now applying instruction: toggle 277,130 through 513,244
# now applying instruction: turn off 62,266 through 854,434
# now applying instruction: turn on 792,764 through 872,842
# now applying instruction: turn off 160,949 through 273,989
# now applying instruction: turn off 664,203 through 694,754
# now applying instruction: toggle 491,615 through 998,836
# now applying instruction: turn off 210,146 through 221,482
# now applying instruction: turn off 209,780 through 572,894
# now applying instruction: turn on 766,112 through 792,868
# now applying instruction: turn on 222,12 through 856,241
# 14687245
